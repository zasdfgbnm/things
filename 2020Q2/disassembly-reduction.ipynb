# %% [markdown]
# # Old code

# %%
import disasm

disasm.FILE = '/home/gaoxiang/.local/lib/python3.8/site-packages/torch/lib/libtorch_cuda.so'

def filter_(demangled_symbol, code):
    ret = True
    ret &= 'sum' in demangled_symbol
    ret &= 'Half' in demangled_symbol
    return ret

disasm.run('ReduceOpsKernel.sm_75.cubin', filter_)
# Out:
# 1.6.0a0+e5746ee
# e5746eec1eeae9636d0f158555134b006b40d3c3
#
# Running:
# rm -rf ReduceOpsKernel.sm_75.cubin; cuobjdump -xelf ReduceOpsKernel.sm_75.cubin /home/gaoxiang/.local/lib/python3.8/site-packages/torch/lib/libtorch_cuda.so
#
# **Symbol:**
# void at::native::reduce_kernel<512, at::native::ReduceOp<c10::Half, at::native::func_wrapper_t<float, at::native::sum_kernel_impl<c10::Half, float, float>(at::TensorIterator&)::{lambda(float, float)#1}>, unsigned int, float, 4> >(at::native::ReduceOp<c10::Half, at::native::func_wrapper_t<float, at::native::sum_kernel_impl<c10::Half, float, float>(at::TensorIterator&)::{lambda(float, float)#1}>, unsigned int, float, 4>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIfZNS0_15sum_kernel_implIS4_ffEEvRNS_14TensorIteratorEEUlffE_EEjfLi4EEEEEvT0_,"ax",@progbits
# 	.sectionflags	@"SHF_BARRIERS=1"
# 	.sectioninfo	@"SHI_REGISTERS=28"
# 	.align	128
#         .global         _ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIfZNS0_15sum_kernel_implIS4_ffEEvRNS_14TensorIteratorEEUlffE_EEjfLi4EEEEEvT0_
#         .type           _ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIfZNS0_15sum_kernel_implIS4_ffEEvRNS_14TensorIteratorEEUlffE_EEjfLi4EEEEEvT0_,@function
#         .size           _ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIfZNS0_15sum_kernel_implIS4_ffEEvRNS_14TensorIteratorEEUlffE_EEjfLi4EEEEEvT0_,(.L_11041 - _ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIfZNS0_15sum_kernel_implIS4_ffEEvRNS_14TensorIteratorEEUlffE_EEjfLi4EEEEEvT0_)
#         .other          _ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIfZNS0_15sum_kernel_implIS4_ffEEvRNS_14TensorIteratorEEUlffE_EEjfLi4EEEEEvT0_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIfZNS0_15sum_kernel_implIS4_ffEEvRNS_14TensorIteratorEEUlffE_EEjfLi4EEEEEvT0_:
# .text._ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIfZNS0_15sum_kernel_implIS4_ffEEvRNS_14TensorIteratorEEUlffE_EEjfLi4EEEEEvT0_:
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 339
#         /*0000*/                   MOV R1, c[0x0][0x28] ;
#         /*0010*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0020*/                   ISETP.NE.AND P0, PT, RZ, c[0x0][0x334], PT ;
#         /*0030*/                   ULDC.U8 UR6, c[0x0][0x568] ;
#         /*0040*/                   MOV R2, RZ ;
#         /*0050*/                   ULDC.U8 UR7, c[0x0][0x569] ;
#         /*0060*/                   IMAD.MOV.U32 R4, RZ, RZ, RZ ;
#         /*0070*/                   ULOP3.LUT UR6, UR6, 0xff, URZ, 0xc0, !UP7 ;
#         /*0080*/                   ULOP3.LUT UR7, UR7, 0xff, URZ, 0xc0, !UP7 ;
#         /*0090*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 339
#         /*00a0*/                   S2R R3, SR_TID.Y ;
#         /*00b0*/                   IMAD R2, R0, c[0x0][0x18c], RZ ;
#         /*00c0*/                   S2R R5, SR_CTAID.X ;
#         /*00d0*/                   IMAD R2, R3, c[0x0][0x190], R2 ;
#         /*00e0*/                   IMAD R3, R5, c[0x0][0x178], R2 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*00f0*/                   MOV R2, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0100*/                   IMAD.MOV.U32 R5, RZ, RZ, c[0x0][0x334] ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0110*/                   IMAD.HI.U32 R6, R3, c[0x0][0x33c], R2 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0120*/                   ISETP.NE.AND P0, PT, R5, 0x1, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0130*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x340], R6 ;
#         /*0140*/                   IADD3 R2, -R7, RZ, RZ ;
#         /*0150*/                   IMAD R3, R2, c[0x0][0x338], R3 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0160*/                   IMAD R2, R3.reuse, c[0x0][0x464], RZ ;
#         /*0170*/                   IMAD R4, R3, c[0x0][0x468], RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0180*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0190*/                   MOV R6, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*01a0*/                   ISETP.NE.AND P0, PT, R5, 0x2, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*01b0*/                   IMAD.HI.U32 R8, R7, c[0x0][0x348], R6 ;
#         /*01c0*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x34c], R8 ;
#         /*01d0*/                   IADD3 R6, -R9, RZ, RZ ;
#         /*01e0*/                   IMAD R6, R6, c[0x0][0x344], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*01f0*/                   IMAD R2, R6.reuse, c[0x0][0x46c], RZ ;
#         /*0200*/                   IMAD R4, R6, c[0x0][0x470], RZ ;
#         /*0210*/                   IMAD R2, R3.reuse, c[0x0][0x464], R2 ;
#         /*0220*/                   IMAD R4, R3, c[0x0][0x468], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0230*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0240*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0250*/                   ISETP.NE.AND P0, PT, R5, 0x3, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0260*/                   IMAD.HI.U32 R6, R9, c[0x0][0x354], R8 ;
#         /*0270*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x358], R6 ;
#         /*0280*/                   IADD3 R3, -R7, RZ, RZ ;
#         /*0290*/                   IMAD R9, R3, c[0x0][0x350], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*02a0*/                   IMAD R2, R9.reuse, c[0x0][0x474], R2 ;
#         /*02b0*/                   IMAD R4, R9, c[0x0][0x478], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*02c0*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*02d0*/                   MOV R6, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*02e0*/                   ISETP.NE.AND P0, PT, R5, 0x4, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*02f0*/                   IMAD.HI.U32 R8, R7, c[0x0][0x360], R6 ;
#         /*0300*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x364], R8 ;
#         /*0310*/                   IMAD.MOV R3, RZ, RZ, -R9 ;
#         /*0320*/                   IMAD R7, R3, c[0x0][0x35c], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0330*/                   IMAD R2, R7.reuse, c[0x0][0x47c], R2 ;
#         /*0340*/                   IMAD R4, R7, c[0x0][0x480], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0350*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0360*/                   MOV R8, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0370*/                   ISETP.NE.AND P0, PT, R5, 0x5, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0380*/                   IMAD.HI.U32 R6, R9, c[0x0][0x36c], R8 ;
#         /*0390*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x370], R6 ;
#         /*03a0*/                   IADD3 R3, -R7, RZ, RZ ;
#         /*03b0*/                   IMAD R9, R3, c[0x0][0x368], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*03c0*/                   IMAD R2, R9.reuse, c[0x0][0x484], R2 ;
#         /*03d0*/                   IMAD R4, R9, c[0x0][0x488], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*03e0*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*03f0*/                   IMAD.MOV.U32 R6, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0400*/                   ISETP.NE.AND P0, PT, R5, 0x6, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0410*/                   IMAD.HI.U32 R8, R7, c[0x0][0x378], R6 ;
#         /*0420*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x37c], R8 ;
#         /*0430*/                   IADD3 R3, -R9, RZ, RZ ;
#         /*0440*/                   IMAD R7, R3, c[0x0][0x374], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0450*/                   IMAD R2, R7.reuse, c[0x0][0x48c], R2 ;
#         /*0460*/                   IMAD R4, R7, c[0x0][0x490], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0470*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0480*/                   MOV R8, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0490*/                   ISETP.NE.AND P0, PT, R5, 0x7, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*04a0*/                   IMAD.HI.U32 R6, R9, c[0x0][0x384], R8 ;
#         /*04b0*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x388], R6 ;
#         /*04c0*/                   IMAD.MOV R3, RZ, RZ, -R7 ;
#         /*04d0*/                   IMAD R9, R3, c[0x0][0x380], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*04e0*/                   IMAD R2, R9.reuse, c[0x0][0x494], R2 ;
#         /*04f0*/                   IMAD R4, R9, c[0x0][0x498], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0500*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0510*/                   MOV R6, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0520*/                   ISETP.NE.AND P0, PT, R5, 0x8, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0530*/                   IMAD.HI.U32 R8, R7, c[0x0][0x390], R6 ;
#         /*0540*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x394], R8 ;
#         /*0550*/                   IADD3 R3, -R9, RZ, RZ ;
#         /*0560*/                   IMAD R7, R3, c[0x0][0x38c], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0570*/                   IMAD R2, R7.reuse, c[0x0][0x49c], R2 ;
#         /*0580*/                   IMAD R4, R7, c[0x0][0x4a0], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0590*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*05a0*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*05b0*/                   ISETP.NE.AND P0, PT, R5, 0x9, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*05c0*/                   IMAD.HI.U32 R6, R9, c[0x0][0x39c], R8 ;
#         /*05d0*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x3a0], R6 ;
#         /*05e0*/                   IADD3 R3, -R7, RZ, RZ ;
#         /*05f0*/                   IMAD R9, R3, c[0x0][0x398], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0600*/                   IMAD R2, R9.reuse, c[0x0][0x4a4], R2 ;
#         /*0610*/                   IMAD R4, R9, c[0x0][0x4a8], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0620*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0630*/                   MOV R6, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0640*/                   ISETP.NE.AND P0, PT, R5, 0xa, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0650*/                   IMAD.HI.U32 R8, R7, c[0x0][0x3a8], R6 ;
#         /*0660*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x3ac], R8 ;
#         /*0670*/                   IMAD.MOV R3, RZ, RZ, -R9 ;
#         /*0680*/                   IMAD R7, R3, c[0x0][0x3a4], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0690*/                   IMAD R2, R7.reuse, c[0x0][0x4ac], R2 ;
#         /*06a0*/                   IMAD R4, R7, c[0x0][0x4b0], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*06b0*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*06c0*/                   MOV R8, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*06d0*/                   ISETP.NE.AND P0, PT, R5, 0xb, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*06e0*/                   IMAD.HI.U32 R6, R9, c[0x0][0x3b4], R8 ;
#         /*06f0*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x3b8], R6 ;
#         /*0700*/                   IADD3 R3, -R7, RZ, RZ ;
#         /*0710*/                   IMAD R9, R3, c[0x0][0x3b0], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0720*/                   IMAD R2, R9.reuse, c[0x0][0x4b4], R2 ;
#         /*0730*/                   IMAD R4, R9, c[0x0][0x4b8], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0740*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0750*/                   IMAD.MOV.U32 R6, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0760*/                   ISETP.NE.AND P0, PT, R5, 0xc, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0770*/                   IMAD.HI.U32 R8, R7, c[0x0][0x3c0], R6 ;
#         /*0780*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x3c4], R8 ;
#         /*0790*/                   IADD3 R3, -R9, RZ, RZ ;
#         /*07a0*/                   IMAD R7, R3, c[0x0][0x3bc], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*07b0*/                   IMAD R2, R7.reuse, c[0x0][0x4bc], R2 ;
#         /*07c0*/                   IMAD R4, R7, c[0x0][0x4c0], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*07d0*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*07e0*/                   MOV R8, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*07f0*/                   ISETP.NE.AND P0, PT, R5, 0xd, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0800*/                   IMAD.HI.U32 R6, R9, c[0x0][0x3cc], R8 ;
#         /*0810*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x3d0], R6 ;
#         /*0820*/                   IMAD.MOV R3, RZ, RZ, -R7 ;
#         /*0830*/                   IMAD R9, R3, c[0x0][0x3c8], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0840*/                   IMAD R2, R9.reuse, c[0x0][0x4c4], R2 ;
#         /*0850*/                   IMAD R4, R9, c[0x0][0x4c8], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0860*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0870*/                   MOV R6, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0880*/                   ISETP.NE.AND P0, PT, R5, 0xe, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0890*/                   IMAD.HI.U32 R8, R7, c[0x0][0x3d8], R6 ;
#         /*08a0*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x3dc], R8 ;
#         /*08b0*/                   IADD3 R3, -R9, RZ, RZ ;
#         /*08c0*/                   IMAD R7, R3, c[0x0][0x3d4], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*08d0*/                   IMAD R2, R7.reuse, c[0x0][0x4cc], R2 ;
#         /*08e0*/                   IMAD R4, R7, c[0x0][0x4d0], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*08f0*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0900*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0910*/                   ISETP.NE.AND P0, PT, R5, 0xf, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0920*/                   IMAD.HI.U32 R6, R9, c[0x0][0x3e4], R8 ;
#         /*0930*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x3e8], R6 ;
#         /*0940*/                   IADD3 R3, -R7, RZ, RZ ;
#         /*0950*/                   IMAD R9, R3, c[0x0][0x3e0], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0960*/                   IMAD R2, R9.reuse, c[0x0][0x4d4], R2 ;
#         /*0970*/                   IMAD R4, R9, c[0x0][0x4d8], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0980*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0990*/                   MOV R6, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*09a0*/                   ISETP.NE.AND P0, PT, R5, 0x10, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*09b0*/                   IMAD.HI.U32 R8, R7, c[0x0][0x3f0], R6 ;
#         /*09c0*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x3f4], R8 ;
#         /*09d0*/                   IMAD.MOV R3, RZ, RZ, -R9 ;
#         /*09e0*/                   IMAD R7, R3, c[0x0][0x3ec], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*09f0*/                   IMAD R2, R7.reuse, c[0x0][0x4dc], R2 ;
#         /*0a00*/                   IMAD R4, R7, c[0x0][0x4e0], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0a10*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0a20*/                   MOV R8, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0a30*/                   ISETP.NE.AND P0, PT, R5, 0x11, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0a40*/                   IMAD.HI.U32 R6, R9, c[0x0][0x3fc], R8 ;
#         /*0a50*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x400], R6 ;
#         /*0a60*/                   IADD3 R3, -R7, RZ, RZ ;
#         /*0a70*/                   IMAD R9, R3, c[0x0][0x3f8], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0a80*/                   IMAD R2, R9.reuse, c[0x0][0x4e4], R2 ;
#         /*0a90*/                   IMAD R4, R9, c[0x0][0x4e8], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0aa0*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0ab0*/                   IMAD.MOV.U32 R6, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0ac0*/                   ISETP.NE.AND P0, PT, R5, 0x12, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0ad0*/                   IMAD.HI.U32 R8, R7, c[0x0][0x408], R6 ;
#         /*0ae0*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x40c], R8 ;
#         /*0af0*/                   IADD3 R3, -R9, RZ, RZ ;
#         /*0b00*/                   IMAD R7, R3, c[0x0][0x404], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0b10*/                   IMAD R2, R7.reuse, c[0x0][0x4ec], R2 ;
#         /*0b20*/                   IMAD R4, R7, c[0x0][0x4f0], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0b30*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0b40*/                   MOV R8, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0b50*/                   ISETP.NE.AND P0, PT, R5, 0x13, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0b60*/                   IMAD.HI.U32 R6, R9, c[0x0][0x414], R8 ;
#         /*0b70*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x418], R6 ;
#         /*0b80*/                   IMAD.MOV R3, RZ, RZ, -R7 ;
#         /*0b90*/                   IMAD R9, R3, c[0x0][0x410], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0ba0*/                   IMAD R2, R9.reuse, c[0x0][0x4f4], R2 ;
#         /*0bb0*/                   IMAD R4, R9, c[0x0][0x4f8], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0bc0*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0bd0*/                   MOV R6, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0be0*/                   ISETP.NE.AND P0, PT, R5, 0x14, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0bf0*/                   IMAD.HI.U32 R8, R7, c[0x0][0x420], R6 ;
#         /*0c00*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x424], R8 ;
#         /*0c10*/                   IADD3 R3, -R9, RZ, RZ ;
#         /*0c20*/                   IMAD R7, R3, c[0x0][0x41c], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0c30*/                   IMAD R2, R7.reuse, c[0x0][0x4fc], R2 ;
#         /*0c40*/                   IMAD R4, R7, c[0x0][0x500], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0c50*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0c60*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0c70*/                   ISETP.NE.AND P0, PT, R5, 0x15, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0c80*/                   IMAD.HI.U32 R6, R9, c[0x0][0x42c], R8 ;
#         /*0c90*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x430], R6 ;
#         /*0ca0*/                   IADD3 R3, -R7, RZ, RZ ;
#         /*0cb0*/                   IMAD R9, R3, c[0x0][0x428], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0cc0*/                   IMAD R2, R9.reuse, c[0x0][0x504], R2 ;
#         /*0cd0*/                   IMAD R4, R9, c[0x0][0x508], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0ce0*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0cf0*/                   MOV R6, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0d00*/                   ISETP.NE.AND P0, PT, R5, 0x16, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0d10*/                   IMAD.HI.U32 R8, R7, c[0x0][0x438], R6 ;
#         /*0d20*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x43c], R8 ;
#         /*0d30*/                   IMAD.MOV R3, RZ, RZ, -R9 ;
#         /*0d40*/                   IMAD R7, R3, c[0x0][0x434], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0d50*/                   IMAD R2, R7.reuse, c[0x0][0x50c], R2 ;
#         /*0d60*/                   IMAD R4, R7, c[0x0][0x510], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0d70*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0d80*/                   MOV R8, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0d90*/                   ISETP.NE.AND P0, PT, R5, 0x17, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0da0*/                   IMAD.HI.U32 R6, R9, c[0x0][0x444], R8 ;
#         /*0db0*/                   SHF.R.U32.HI R7, RZ, c[0x0][0x448], R6 ;
#         /*0dc0*/                   IADD3 R3, -R7, RZ, RZ ;
#         /*0dd0*/                   IMAD R9, R3, c[0x0][0x440], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0de0*/                   IMAD R2, R9.reuse, c[0x0][0x514], R2 ;
#         /*0df0*/                   IMAD R4, R9, c[0x0][0x518], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0e00*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0e10*/                   IMAD.MOV.U32 R6, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0e20*/                   ISETP.NE.AND P0, PT, R5, 0x18, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0e30*/                   IMAD.HI.U32 R8, R7, c[0x0][0x450], R6 ;
#         /*0e40*/                   SHF.R.U32.HI R9, RZ, c[0x0][0x454], R8 ;
#         /*0e50*/                   IADD3 R3, -R9, RZ, RZ ;
#         /*0e60*/                   IMAD R7, R3, c[0x0][0x44c], R7 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0e70*/                   IMAD R2, R7.reuse, c[0x0][0x51c], R2 ;
#         /*0e80*/                   IMAD R4, R7, c[0x0][0x520], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*0e90*/              @!P0 BRA `(.L_6721) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*0ea0*/                   MOV R8, RZ ;
#         /*0eb0*/                   IMAD.HI.U32 R3, R9, c[0x0][0x45c], R8 ;
#         /*0ec0*/                   SHF.R.U32.HI R3, RZ, c[0x0][0x460], R3 ;
#         /*0ed0*/                   IMAD.MOV R3, RZ, RZ, -R3 ;
#         /*0ee0*/                   IMAD R9, R3, c[0x0][0x458], R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*0ef0*/                   IMAD R2, R9.reuse, c[0x0][0x524], R2 ;
#         /*0f00*/                   IMAD R4, R9, c[0x0][0x528], R4 ;
# .L_6721:
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 339
#         /*0f10*/                   S2R R7, SR_TID.Y ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 340
#         /*0f20*/                   IMAD R6, R0.reuse, c[0x0][0x180], RZ ;
#         /*0f30*/                   BMOV.32.CLEAR RZ, B2 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 339
#         /*0f40*/                   IMAD R8, R0, c[0x0][0x18c], RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 340
#         /*0f50*/                   S2R R3, SR_CTAID.Y ;
#         /*0f60*/                   BSSY B2, `(.L_6722) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 344
#         /*0f70*/                   MOV R9, c[0x0][0x164] ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 339
#         /*0f80*/                   S2R R5, SR_CTAID.X ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 340
#         /*0f90*/                   IMAD R6, R7, c[0x0][0x184], R6 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 339
#         /*0fa0*/                   IMAD R8, R7, c[0x0][0x190], R8 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 340
#         /*0fb0*/                   IMAD R6, R3, c[0x0][0x188], R6 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 339
#         /*0fc0*/                   IMAD R3, R5, c[0x0][0x178], R8 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 344
#         /*0fd0*/                   ISETP.GE.U32.AND P0, PT, R6, c[0x0][0x16c], PT ;
#         /*0fe0*/                   ISETP.GE.U32.OR P0, PT, R3, c[0x0][0x170], P0 ;
#         /*0ff0*/               @P0 BRA `(.L_6723) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 340
#         /*1000*/                   MOV R5, c[0x0][0x1a0] ;
#         /*1010*/                   BMOV.32.CLEAR RZ, B1 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 345
#         /*1020*/                   IADD3 R4, P1, R4, c[0x0][0x530], RZ ;
#         /*1030*/                   BSSY B1, `(.L_6724) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 340
#         /*1040*/                   IMAD.MOV.U32 R9, RZ, RZ, R6 ;
#         /*1050*/                   ISETP.NE.AND P0, PT, R5, 0x1, PT ;
#         /*1060*/                   IMAD.MOV.U32 R8, RZ, RZ, c[0x0][0x164] ;
#         /*1070*/                   MOV R6, c[0x0][0x164] ;
#         /*1080*/                   MOV R11, c[0x0][0x164] ;
#         /*1090*/                   MOV R10, c[0x0][0x164] ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 345
#         /*10a0*/                   IADD3.X R5, RZ, c[0x0][0x534], RZ, P1, !PT ;
# .L_6744:
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 340
#         /*10b0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*10c0*/                   BSSY B0, `(.L_6725) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 411
#         /*10d0*/              @!P0 BRA `(.L_6726) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 227
#         /*10e0*/                   IMAD.MOV.U32 R12, RZ, RZ, c[0x0][0x174] ;
#         /*10f0*/                   IMAD R13, R12, 0x3, R9 ;
#         /*1100*/                   ISETP.GE.U32.AND P1, PT, R13, c[0x0][0x16c], PT ;
#         /*1110*/              @!P1 BRA `(.L_6727) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 236
#         /*1120*/                   ISETP.GE.U32.AND P1, PT, R9, c[0x0][0x16c], PT ;
#         /*1130*/                   BMOV.32.CLEAR RZ, B3 ;
#         /*1140*/                   BSSY B3, `(.L_6728) ;
#         /*1150*/               @P1 BRA `(.L_6729) ;
#         /*1160*/                   ISETP.NE.AND P1, PT, RZ, c[0x0][0x1a0], PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1170*/                   MOV R17, RZ ;
#         /*1180*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1190*/                   MOV R18, RZ ;
#         /*11a0*/                   IMAD.MOV.U32 R19, RZ, RZ, R9 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*11b0*/                   IMAD.MOV.U32 R22, RZ, RZ, c[0x0][0x1a0] ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*11c0*/                   IMAD.HI.U32 R18, R9, c[0x0][0x1a8], R18 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*11d0*/                   ISETP.NE.AND P1, PT, R22, 0x2, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*11e0*/                   SHF.R.U32.HI R19, RZ, c[0x0][0x1ac], R18 ;
#         /*11f0*/                   MOV R18, RZ ;
#         /*1200*/                   IADD3 R24, -R19, RZ, RZ ;
#         /*1210*/                   IMAD.HI.U32 R20, R19, c[0x0][0x1b4], R18 ;
#         /*1220*/                   IMAD R17, R24, c[0x0][0x1a4], R9 ;
#         /*1230*/                   SHF.R.U32.HI R21, RZ, c[0x0][0x1b8], R20 ;
#         /*1240*/                   IADD3 R18, -R21, RZ, RZ ;
#         /*1250*/                   IMAD R18, R18, c[0x0][0x1b0], R19 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*1260*/                   IMAD R18, R18, c[0x0][0x2d4], RZ ;
#         /*1270*/                   IMAD R17, R17, c[0x0][0x2d0], R18 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1280*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1290*/                   MOV R20, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*12a0*/                   ISETP.NE.AND P1, PT, R22, 0x3, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*12b0*/                   IMAD.HI.U32 R18, R21, c[0x0][0x1c0], R20 ;
#         /*12c0*/                   SHF.R.U32.HI R19, RZ, c[0x0][0x1c4], R18 ;
#         /*12d0*/                   IMAD.MOV R20, RZ, RZ, -R19 ;
#         /*12e0*/                   IMAD R20, R20, c[0x0][0x1bc], R21 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*12f0*/                   IMAD R17, R20, c[0x0][0x2d8], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1300*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1310*/                   MOV R18, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1320*/                   ISETP.NE.AND P1, PT, R22, 0x4, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1330*/                   IMAD.HI.U32 R20, R19, c[0x0][0x1cc], R18 ;
#         /*1340*/                   SHF.R.U32.HI R21, RZ, c[0x0][0x1d0], R20 ;
#         /*1350*/                   IADD3 R18, -R21, RZ, RZ ;
#         /*1360*/                   IMAD R18, R18, c[0x0][0x1c8], R19 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*1370*/                   IMAD R17, R18, c[0x0][0x2dc], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1380*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1390*/                   IMAD.MOV.U32 R20, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*13a0*/                   ISETP.NE.AND P1, PT, R22, 0x5, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*13b0*/                   IMAD.HI.U32 R18, R21, c[0x0][0x1d8], R20 ;
#         /*13c0*/                   SHF.R.U32.HI R19, RZ, c[0x0][0x1dc], R18 ;
#         /*13d0*/                   IADD3 R20, -R19, RZ, RZ ;
#         /*13e0*/                   IMAD R20, R20, c[0x0][0x1d4], R21 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*13f0*/                   IMAD R17, R20, c[0x0][0x2e0], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1400*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1410*/                   MOV R18, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1420*/                   ISETP.NE.AND P1, PT, R22, 0x6, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1430*/                   IMAD.HI.U32 R20, R19, c[0x0][0x1e4], R18 ;
#         /*1440*/                   SHF.R.U32.HI R21, RZ, c[0x0][0x1e8], R20 ;
#         /*1450*/                   IMAD.MOV R18, RZ, RZ, -R21 ;
#         /*1460*/                   IMAD R18, R18, c[0x0][0x1e0], R19 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*1470*/                   IMAD R17, R18, c[0x0][0x2e4], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1480*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1490*/                   MOV R20, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*14a0*/                   ISETP.NE.AND P1, PT, R22, 0x7, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*14b0*/                   IMAD.HI.U32 R18, R21, c[0x0][0x1f0], R20 ;
#         /*14c0*/                   SHF.R.U32.HI R19, RZ, c[0x0][0x1f4], R18 ;
#         /*14d0*/                   IADD3 R20, -R19, RZ, RZ ;
#         /*14e0*/                   IMAD R20, R20, c[0x0][0x1ec], R21 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*14f0*/                   IMAD R17, R20, c[0x0][0x2e8], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1500*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1510*/                   IMAD.MOV.U32 R18, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1520*/                   ISETP.NE.AND P1, PT, R22, 0x8, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1530*/                   IMAD.HI.U32 R20, R19, c[0x0][0x1fc], R18 ;
#         /*1540*/                   SHF.R.U32.HI R21, RZ, c[0x0][0x200], R20 ;
#         /*1550*/                   IADD3 R18, -R21, RZ, RZ ;
#         /*1560*/                   IMAD R18, R18, c[0x0][0x1f8], R19 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*1570*/                   IMAD R17, R18, c[0x0][0x2ec], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1580*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1590*/                   MOV R20, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*15a0*/                   ISETP.NE.AND P1, PT, R22, 0x9, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*15b0*/                   IMAD.HI.U32 R18, R21, c[0x0][0x208], R20 ;
#         /*15c0*/                   SHF.R.U32.HI R19, RZ, c[0x0][0x20c], R18 ;
#         /*15d0*/                   IMAD.MOV R20, RZ, RZ, -R19 ;
#         /*15e0*/                   IMAD R20, R20, c[0x0][0x204], R21 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*15f0*/                   IMAD R17, R20, c[0x0][0x2f0], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1600*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1610*/                   MOV R18, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1620*/                   ISETP.NE.AND P1, PT, R22, 0xa, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1630*/                   IMAD.HI.U32 R20, R19, c[0x0][0x214], R18 ;
#         /*1640*/                   SHF.R.U32.HI R21, RZ, c[0x0][0x218], R20 ;
#         /*1650*/                   IADD3 R18, -R21, RZ, RZ ;
#         /*1660*/                   IMAD R18, R18, c[0x0][0x210], R19 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*1670*/                   IMAD R17, R18, c[0x0][0x2f4], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1680*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1690*/                   IMAD.MOV.U32 R20, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*16a0*/                   ISETP.NE.AND P1, PT, R22, 0xb, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*16b0*/                   IMAD.HI.U32 R18, R21, c[0x0][0x220], R20 ;
#         /*16c0*/                   SHF.R.U32.HI R19, RZ, c[0x0][0x224], R18 ;
#         /*16d0*/                   IADD3 R20, -R19, RZ, RZ ;
#         /*16e0*/                   IMAD R20, R20, c[0x0][0x21c], R21 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*16f0*/                   IMAD R17, R20, c[0x0][0x2f8], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1700*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1710*/                   MOV R18, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1720*/                   ISETP.NE.AND P1, PT, R22, 0xc, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1730*/                   IMAD.HI.U32 R20, R19, c[0x0][0x22c], R18 ;
#         /*1740*/                   SHF.R.U32.HI R21, RZ, c[0x0][0x230], R20 ;
#         /*1750*/                   IMAD.MOV R18, RZ, RZ, -R21 ;
#         /*1760*/                   IMAD R18, R18, c[0x0][0x228], R19 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*1770*/                   IMAD R17, R18, c[0x0][0x2fc], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1780*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1790*/                   MOV R20, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*17a0*/                   ISETP.NE.AND P1, PT, R22, 0xd, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*17b0*/                   IMAD.HI.U32 R18, R21, c[0x0][0x238], R20 ;
#         /*17c0*/                   SHF.R.U32.HI R19, RZ, c[0x0][0x23c], R18 ;
#         /*17d0*/                   IADD3 R20, -R19, RZ, RZ ;
#         /*17e0*/                   IMAD R20, R20, c[0x0][0x234], R21 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 61
#         /*17f0*/                   IMAD R17, R20, c[0x0][0x300], R17 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1800*/              @!P1 BRA `(.L_6730) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1810*/                   IMAD.MOV.U32 R18, RZ, RZ, RZ ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/cuda/detail/OffsetCalculator.cuh", line 53
#         /*1820*/                   ISETP.NE.AND P1, PT, R22, 0xe, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/THC/THCIntegerDivider.cuh", line 100
#         /*1830*/                   IMAD.HI.U32 R20, R19, c[0x0][0x244], R18 ;
#         /*1840*/                   SHF.R.U32.HI R21, RZ, c[0x0][0x248], R20 ;
# ...
#         /*9250*/               @P0 EXIT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 614
#         /*9260*/                   STG.E.SYS [R8], R11 ;
#         /*9270*/                   EXIT ;
# .L_6844:
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 612
#         /*9280*/                   ISETP.NE.AND P0, PT, RZ, UR6, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 599
#         /*9290*/              @!P0 BRA `(.L_6846) ;
#         /*92a0*/                   LDG.E.U16.SYS R0, [R6] ;
# 	//## File "/opt/cuda/include/cuda_fp16.hpp", line 507
#         /*92b0*/                   HADD2.F32 R0, R0.H0_H0, -RZ.H0_H0 ;
# 	//## File "/home/gaoxiang/pytorch-master/c10/util/Half-inl.h", line 31
#         /*92c0*/                   FADD R11, R11, R0 ;
# .L_6846:
# 	//## File "/opt/cuda/include/cuda_fp16.hpp", line 364
#         /*92d0*/                   F2F.F16.F32 R11, R11 ;
# 	//## File "/home/gaoxiang/pytorch-master/c10/util/Half-inl.h", line 21
#         /*92e0*/                   STG.E.U16.SYS [R6], R11 ;
#         /*92f0*/                   EXIT ;
# .L_6823:
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 339
#         /*9300*/                   S2R R5, SR_TID.Y ;
#         /*9310*/                   IMAD R2, R0.reuse, c[0x0][0x18c], RZ ;
#         /*9320*/                   ISETP.EQ.OR P1, PT, R0, RZ, !P1 ;
#         /*9330*/                   S2R R3, SR_CTAID.X ;
#         /*9340*/                   IMAD R2, R5.reuse, c[0x0][0x190], R2 ;
#         /*9350*/                   ISETP.EQ.OR P0, PT, R5, RZ, !P0 ;
#         /*9360*/                   IMAD R2, R3, c[0x0][0x178], R2 ;
#         /*9370*/                   ISETP.LT.AND P1, PT, R2, c[0x0][0x170], P1 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 367
#         /*9380*/                   PLOP3.LUT P1, PT, P1, P0, PT, 0x80, 0x0 ;
#         /*9390*/              @!P1 EXIT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 372
#         /*93a0*/                   ISETP.NE.U32.AND P0, PT, R8, RZ, PT ;
#         /*93b0*/                   ISETP.NE.AND.EX P0, PT, R10, RZ, PT, P0 ;
#         /*93c0*/              @!P0 BRA `(.L_6847) ;
#         /*93d0*/                   ISETP.NE.AND P0, PT, RZ, UR6, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 382
#         /*93e0*/              @!P0 BRA `(.L_6848) ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 383
#         /*93f0*/                   LDG.E.SYS R3, [R8] ;
#         /*9400*/                   FADD R4, R4, R3 ;
# .L_6848:
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 385
#         /*9410*/                   ISETP.NE.AND P0, PT, RZ, UR7, PT ;
# 	//## File "/opt/cuda/include/cuda_fp16.hpp", line 364
#         /*9420*/               @P0 F2F.F16.F32 R3, R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 386
#         /*9430*/               @P0 STG.E.U16.SYS [R6], R3 ;
#         /*9440*/               @P0 EXIT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 388
#         /*9450*/                   STG.E.SYS [R8], R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 199
#         /*9460*/                   EXIT ;
# .L_6847:
# 	//## File "/home/gaoxiang/pytorch-master/c10/util/Half-inl.h", line 21
#         /*9470*/                   ISETP.NE.AND P0, PT, RZ, UR6, PT ;
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 373
#         /*9480*/              @!P0 BRA `(.L_6849) ;
#         /*9490*/                   LDG.E.U16.SYS R0, [R6] ;
# 	//## File "/opt/cuda/include/cuda_fp16.hpp", line 507
#         /*94a0*/                   HADD2.F32 R3, R0.H0_H0, -RZ.H0_H0 ;
# 	//## File "/home/gaoxiang/pytorch-master/c10/util/Half-inl.h", line 31
#         /*94b0*/                   FADD R4, R4, R3 ;
# .L_6849:
# 	//## File "/opt/cuda/include/cuda_fp16.hpp", line 364
#         /*94c0*/                   F2F.F16.F32 R3, R4 ;
# 	//## File "/home/gaoxiang/pytorch-master/c10/util/Half-inl.h", line 21
#         /*94d0*/                   STG.E.U16.SYS [R6], R3 ;
#         /*94e0*/                   EXIT ;
#         .weak           $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_div_u64
#         .type           $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_div_u64,@function
#         .size           $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_div_u64,($_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_rem_u64 - $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_div_u64)
# $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_div_u64:
# 	//## File "/home/gaoxiang/pytorch-master/aten/src/ATen/native/cuda/Reduce.cuh", line 199
#         /*94f0*/                   IMAD.MOV.U32 R20, RZ, RZ, R8 ;
#         /*9500*/                   MOV R21, R9 ;
#         /*9510*/                   I2F.U64.RP R15, R20 ;
#         /*9520*/                   MUFU.RCP R15, R15 ;
#         /*9530*/                   IADD3 R16, R15, 0x1ffffffe, RZ ;
#         /*9540*/                   F2I.U64.TRUNC R16, R16 ;
#         /*9550*/                   IMAD.WIDE.U32 R18, R16, R8, RZ ;
#         /*9560*/                   IMAD R19, R16, R9, R19 ;
#         /*9570*/                   IADD3 R23, P2, RZ, -R18, RZ ;
#         /*9580*/                   IMAD R19, R17, R8, R19 ;
#         /*9590*/                   IMAD.HI.U32 R18, R16, R23, RZ ;
#         /*95a0*/                   IADD3.X R25, RZ, ~R19, RZ, P2, !PT ;
#         /*95b0*/                   IMAD.MOV.U32 R19, RZ, RZ, R16 ;
#         /*95c0*/                   IMAD.WIDE.U32 R18, P2, R16, R25, R18 ;
#         /*95d0*/                   IMAD R21, R17.reuse, R25.reuse, RZ ;
#         /*95e0*/                   IMAD.HI.U32 R16, R17.reuse, R25, RZ ;
#         /*95f0*/                   IMAD.HI.U32 R18, P3, R17, R23, R18 ;
#         /*9600*/                   IADD3.X R16, R16, R17, RZ, P2, !PT ;
#         /*9610*/                   MOV R17, RZ ;
#         /*9620*/                   IADD3 R21, P5, R21, R18, RZ ;
#         /*9630*/                   IADD3.X R15, RZ, RZ, R16, P5, P3 ;
#         /*9640*/                   IMAD.WIDE.U32 R18, R21, R8, RZ ;
#         /*9650*/                   IMAD R16, R21, R9, R19 ;
#         /*9660*/                   IADD3 R19, P2, RZ, -R18, RZ ;
#         /*9670*/                   IMAD R16, R15, R8, R16 ;
#         /*9680*/                   IMAD.HI.U32 R20, R21, R19, RZ ;
#         /*9690*/                   IADD3.X R16, RZ, ~R16, RZ, P2, !PT ;
#         /*96a0*/                   IMAD.WIDE.U32 R20, P2, R21, R16, R20 ;
#         /*96b0*/                   IMAD R18, R15, R16, RZ ;
#         /*96c0*/                   IMAD.HI.U32 R19, P3, R15, R19, R20 ;
#         /*96d0*/                   IADD3 R19, P5, R18, R19, RZ ;
#         /*96e0*/                   IMAD.HI.U32 R18, R15, R16, RZ ;
#         /*96f0*/                   IMAD.HI.U32 R16, R19.reuse, R14, RZ ;
#         /*9700*/                   IMAD.X R15, R18, 0x1, R15, P2 ;
#         /*9710*/                   IMAD.WIDE.U32 R16, R19, R13, R16 ;
#         /*9720*/                   IADD3.X R15, RZ, RZ, R15, P5, P3 ;
#         /*9730*/                   IMAD.HI.U32 R16, P2, R15, R14, R16 ;
#         /*9740*/                   IMAD R19, R15.reuse, R13.reuse, RZ ;
#         /*9750*/                   IMAD.HI.U32 R15, R15, R13, RZ ;
#         /*9760*/                   IADD3 R19, P3, R19, R16, RZ ;
#         /*9770*/                   IADD3.X R15, R15, RZ, RZ, P2, !PT ;
#         /*9780*/                   IMAD.WIDE.U32 R16, R19, R8, RZ ;
#         /*9790*/                   IMAD.X R15, RZ, RZ, R15, P3 ;
#         /*97a0*/                   IMAD R17, R19, R9, R17 ;
#         /*97b0*/                   IADD3 R21, P3, -R16, R14, RZ ;
#         /*97c0*/                   IMAD R14, R15, R8.reuse, R17 ;
#         /*97d0*/                   ISETP.GE.U32.AND P2, PT, R21, R8, PT ;
#         /*97e0*/                   IADD3.X R20, ~R14, R13, RZ, P3, !PT ;
#         /*97f0*/                   IADD3 R14, P3, R19, 0x1, RZ ;
#         /*9800*/                   IADD3 R13, P5, -R8, R21, RZ ;
#         /*9810*/                   ISETP.GE.U32.AND.EX P2, PT, R20, R9, PT, P2 ;
#         /*9820*/                   IMAD.X R16, RZ, RZ, R15, P3 ;
#         /*9830*/                   IADD3.X R18, ~R9, R20, RZ, P5, !PT ;
#         /*9840*/                   SEL R13, R13, R21, P2 ;
#         /*9850*/                   SEL R19, R14, R19, P2 ;
#         /*9860*/                   SEL R18, R18, R20, P2 ;
#         /*9870*/                   SEL R16, R16, R15, P2 ;
#         /*9880*/                   ISETP.GE.U32.AND P2, PT, R13, R8, PT ;
#         /*9890*/                   IADD3 R14, P5, R19, 0x1, RZ ;
#         /*98a0*/                   ISETP.NE.U32.AND P3, PT, R8, RZ, PT ;
#         /*98b0*/                   ISETP.GE.U32.AND.EX P2, PT, R18, R9, PT, P2 ;
#         /*98c0*/                   IADD3.X R15, RZ, R16.reuse, RZ, P5, !PT ;
#         /*98d0*/                   MOV R13, 0x0 ;
#         /*98e0*/                   ISETP.NE.AND.EX P3, PT, R9, RZ, PT, P3 ;
#         /*98f0*/                   SEL R14, R14, R19, P2 ;
#         /*9900*/                   SEL R15, R15, R16, P2 ;
#         /*9910*/                   SEL R14, R14, 0xffffffff, P3 ;
#         /*9920*/                   SEL R15, R15, 0xffffffff, P3 ;
#         /*9930*/                   RET.REL.NODEC R12 `(_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_) ;
#         .weak           $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_rem_u64
#         .type           $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_rem_u64,@function
#         .size           $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_rem_u64,(.L_10903 - $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_rem_u64)
# $_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_$__cuda_sm20_rem_u64:
#         /*9940*/                   I2F.U64.RP R15, R12 ;
#         /*9950*/                   MUFU.RCP R15, R15 ;
#         /*9960*/                   IADD3 R16, R15, 0x1ffffffe, RZ ;
#         /*9970*/                   F2I.U64.TRUNC R16, R16 ;
#         /*9980*/                   IMAD.WIDE.U32 R18, R16, R12, RZ ;
#         /*9990*/                   IMAD R19, R16, R13, R19 ;
#         /*99a0*/                   IADD3 R21, P2, RZ, -R18, RZ ;
#         /*99b0*/                   IMAD R19, R17, R12, R19 ;
#         /*99c0*/                   IMAD.HI.U32 R18, R16, R21, RZ ;
#         /*99d0*/                   IMAD.X R23, RZ, RZ, ~R19, P2 ;
#         /*99e0*/                   MOV R19, R16 ;
#         /*99f0*/                   IMAD.WIDE.U32 R18, P2, R16, R23, R18 ;
#         /*9a00*/                   IMAD.HI.U32 R16, R17, R23, RZ ;
#         /*9a10*/                   IMAD.HI.U32 R18, P3, R17, R21, R18 ;
#         /*9a20*/                   IADD3.X R16, R16, R17, RZ, P2, !PT ;
#         /*9a30*/                   IMAD R21, R17, R23, RZ ;
#         /*9a40*/                   MOV R17, RZ ;
#         /*9a50*/                   IADD3 R21, P4, R21, R18, RZ ;
#         /*9a60*/                   IADD3.X R15, RZ, RZ, R16, P4, P3 ;
#         /*9a70*/                   IMAD.WIDE.U32 R18, R21, R12, RZ ;
#         /*9a80*/                   IMAD R16, R21, R13, R19 ;
#         /*9a90*/                   IADD3 R19, P2, RZ, -R18, RZ ;
#         /*9aa0*/                   IMAD R16, R15, R12, R16 ;
#         /*9ab0*/                   IMAD.HI.U32 R20, R21, R19, RZ ;
#         /*9ac0*/                   IMAD.X R16, RZ, RZ, ~R16, P2 ;
#         /*9ad0*/                   IMAD.WIDE.U32 R20, P2, R21, R16, R20 ;
#         /*9ae0*/                   IMAD R18, R15, R16, RZ ;
#         /*9af0*/                   IMAD.HI.U32 R19, P3, R15, R19, R20 ;
#         /*9b00*/                   IADD3 R19, P4, R18, R19, RZ ;
#         /*9b10*/                   IMAD.HI.U32 R18, R15, R16, RZ ;
#         /*9b20*/                   IMAD.HI.U32 R16, R19, R14, RZ ;
#         /*9b30*/                   IADD3.X R15, R18, R15, RZ, P2, !PT ;
#         /*9b40*/                   IMAD.WIDE.U32 R16, R19, R11, R16 ;
#         /*9b50*/                   IADD3.X R15, RZ, RZ, R15, P4, P3 ;
#         /*9b60*/                   IMAD R19, R15.reuse, R11, RZ ;
#         /*9b70*/                   IMAD.HI.U32 R16, P2, R15, R14, R16 ;
#         /*9b80*/                   IMAD.HI.U32 R15, R15, R11, RZ ;
#         /*9b90*/                   IADD3 R19, P3, R19, R16, RZ ;
#         /*9ba0*/                   IMAD.X R15, RZ, RZ, R15, P2 ;
#         /*9bb0*/                   IMAD.WIDE.U32 R16, R19, R12, RZ ;
#         /*9bc0*/                   IADD3.X R15, RZ, R15, RZ, P3, !PT ;
#         /*9bd0*/                   IMAD R19, R19, R13, R17 ;
#         /*9be0*/                   IADD3 R17, P3, -R16, R14, RZ ;
#         /*9bf0*/                   IMAD R14, R15, R12.reuse, R19 ;
#         /*9c00*/                   ISETP.GE.U32.AND P2, PT, R17, R12, PT ;
#         /*9c10*/                   IADD3.X R14, ~R14, R11, RZ, P3, !PT ;
#         /*9c20*/                   IADD3 R15, P3, -R12, R17, RZ ;
#         /*9c30*/                   ISETP.GE.U32.AND.EX P2, PT, R14, R13, PT, P2 ;
#         /*9c40*/                   IMAD.X R16, R14, 0x1, ~R13, P3 ;
#         /*9c50*/                   SEL R15, R15, R17, P2 ;
#         /*9c60*/                   ISETP.NE.U32.AND P3, PT, R12, RZ, PT ;
#         /*9c70*/                   SEL R16, R16, R14, P2 ;
#         /*9c80*/                   ISETP.GE.U32.AND P2, PT, R15, R12, PT ;
#         /*9c90*/                   IADD3 R11, P4, -R12, R15, RZ ;
#         /*9ca0*/                   ISETP.GE.U32.AND.EX P2, PT, R16, R13, PT, P2 ;
#         /*9cb0*/                   IADD3.X R14, ~R13, R16.reuse, RZ, P4, !PT ;
#         /*9cc0*/                   SEL R12, R11, R15, P2 ;
#         /*9cd0*/                   MOV R11, 0x0 ;
#         /*9ce0*/                   ISETP.NE.AND.EX P3, PT, R13, RZ, PT, P3 ;
#         /*9cf0*/                   SEL R13, R14, R16, P2 ;
#         /*9d00*/                   SEL R12, R12, 0xffffffff, P3 ;
#         /*9d10*/                   SEL R13, R13, 0xffffffff, P3 ;
#         /*9d20*/                   RET.REL.NODEC R10 `(_ZN2at6native13reduce_kernelILi512ENS0_8ReduceOpIN3c104HalfENS0_14func_wrapper_tIS4_ZNS0_15sum_kernel_implIS4_fS4_EEvRNS_14TensorIteratorEEUlffE_EEjS4_Li4EEEEEvT0_) ;
# .L_6850:
#         /*9d30*/                   BRA `(.L_6850);
#         /*9d40*/                   NOP;
#         /*9d50*/                   NOP;
#         /*9d60*/                   NOP;
#         /*9d70*/                   NOP;
# .L_10903:

# %% [markdown]
# # New code

# %%
import disasm

def filter_(demangled_symbol, code):
    ret = True
    ret &= 'modern' in demangled_symbol                 # new code
    ret &= 'add_kernel' in demangled_symbol             # add kernel
    ret &= 'lambda(float, float)' in demangled_symbol   # dtype = float
    ret &= 'TypeCast.h' not in code                     # no dynamic casting
    ret &= 'OffsetCalculator.cuh' not in code           # trivial 1d
    return ret

disasm.run('BinaryArithmeticKernel.sm_70.cubin', filter_)
# Out:
# 1.5.0a0+b141ee2
# b141ee2d2536459c1695ef5050faadce52a72686
#
# Running:
# rm -rf BinaryArithmeticKernel.sm_70.cubin; cuobjdump -xelf BinaryArithmeticKernel.sm_70.cubin /home/xgao/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<1, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40896 - _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R2, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R9, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R2, R2, 0x100, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0050*/                   SHF.R.S32.HI R3, RZ, 0x1f, R9 ;
#         /*0060*/                   IADD3 R16, P0, R2.reuse, R9, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0070*/                   IADD3 R0, -R2.reuse, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0080*/                   LEA.HI.X.SX32 R3, R2, R3, 0x1, P0 ;
#         /*0090*/                   IMAD.SHL.U32 R2, R16, 0x4, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*00a0*/                   ISETP.GE.AND P0, PT, R0, 0x100, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*00b0*/                   SHF.L.U64.HI R16, R16, 0x2, R3 ;
#         /*00c0*/                   IADD3 R6, P1, R2, c[0x0][0x188], RZ ;
#         /*00d0*/                   IADD3 R4, P2, R2, c[0x0][0x190], RZ ;
#         /*00e0*/                   IADD3.X R7, R16.reuse, c[0x0][0x18c], RZ, P1, !PT ;
#         /*00f0*/                   IADD3.X R5, R16, c[0x0][0x194], RZ, P2, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*0100*/               @P0 LDG.E.SYS R3, [R6] ;
#         /*0110*/               @P0 LDG.E.SYS R8, [R4] ;
#         /*0120*/               @P0 LDG.E.SYS R10, [R4+0x100] ;
#         /*0130*/               @P0 LDG.E.SYS R13, [R6+0x100] ;
#         /*0140*/               @P0 LDG.E.SYS R12, [R4+0x200] ;
#         /*0150*/               @P0 LDG.E.SYS R15, [R6+0x200] ;
#         /*0160*/               @P0 LDG.E.SYS R14, [R4+0x300] ;
#         /*0170*/               @P0 LDG.E.SYS R17, [R6+0x300] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0180*/                   IADD3 R2, P1, R2, c[0x0][0x180], RZ ;
#         /*0190*/               @P0 FFMA R11, R8, c[0x0][0x168], R3 ;
#         /*01a0*/                   IADD3.X R3, R16, c[0x0][0x184], RZ, P1, !PT ;
#         /*01b0*/               @P0 FFMA R13, R10, c[0x0][0x168], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01c0*/               @P0 STG.E.SYS [R2], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*01d0*/               @P0 FFMA R15, R12, c[0x0][0x168], R15 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01e0*/               @P0 STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*01f0*/               @P0 FFMA R17, R14, c[0x0][0x168], R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0200*/               @P0 STG.E.SYS [R2+0x200], R15 ;
#         /*0210*/               @P0 STG.E.SYS [R2+0x300], R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*0220*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0230*/                   ISETP.GE.AND P0, PT, R9, R0, PT ;
#         /*0240*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0250*/                   BSSY B0, `(.L_3162) ;
#         /*0260*/               @P0 BRA `(.L_3163) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0270*/                   LDG.E.SYS R8, [R6] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0280*/                   IADD3 R11, R9, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0290*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
#         /*02a0*/               @P1 BRA `(.L_3163) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02b0*/                   LDG.E.SYS R10, [R6+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02c0*/                   IADD3 R11, R9, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02d0*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
#         /*02e0*/               @P1 BRA `(.L_3163) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02f0*/                   IADD3 R11, R9, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0300*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0310*/                   LDG.E.SYS R11, [R6+0x200] ;
#         /*0320*/              @!P1 LDG.E.SYS R12, [R6+0x300] ;
# .L_3163:
#         /*0330*/                   BSYNC B0 ;
# .L_3162:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0340*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0350*/                   BSSY B0, `(.L_3164) ;
#         /*0360*/               @P0 BRA `(.L_3165) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0370*/                   LDG.E.SYS R7, [R4] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0380*/                   IADD3 R13, R9, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0390*/                   ISETP.GE.AND P1, PT, R13, R0, PT ;
#         /*03a0*/               @P1 BRA `(.L_3165) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*03b0*/                   LDG.E.SYS R13, [R4+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*03c0*/                   IADD3 R15, R9, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*03d0*/                   ISETP.GE.AND P1, PT, R15, R0, PT ;
#         /*03e0*/               @P1 BRA `(.L_3165) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*03f0*/                   IADD3 R17, R9, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0400*/                   LDG.E.SYS R6, [R4+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0410*/                   ISETP.GE.AND P1, PT, R17, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0420*/              @!P1 LDG.E.SYS R15, [R4+0x300] ;
# .L_3165:
#         /*0430*/                   BSYNC B0 ;
# .L_3164:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0440*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0450*/                   IADD3 R5, R9, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0460*/                   FFMA R7, R7, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0470*/                   ISETP.GE.AND P0, PT, R5, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0480*/                   STG.E.SYS [R2], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0490*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*04a0*/                   IADD3 R5, R9, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*04b0*/                   FFMA R13, R13, c[0x0][0x168], R10 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04c0*/                   ISETP.GE.AND P0, PT, R5, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*04d0*/                   STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04e0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*04f0*/                   IADD3 R9, R9, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0500*/                   FFMA R11, R6, c[0x0][0x168], R11 ;
#         /*0510*/                   FFMA R15, R15, c[0x0][0x168], R12 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0520*/                   ISETP.GE.AND P0, PT, R9, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0530*/                   STG.E.SYS [R2+0x200], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0540*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0550*/                   STG.E.SYS [R2+0x300], R15 ;
#         /*0560*/                   EXIT ;
# .L_3166:
#         /*0570*/                   BRA `(.L_3166);
# .L_40896:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<2, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40897 - _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R9, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R9, R9, 0x100, RZ ;
#         /*0050*/                   IADD3 R5, -R9, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0060*/                   SHF.R.S32.HI R17, RZ, 0x1f, R9 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*0070*/                   ISETP.GE.AND P0, PT, R5, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_3167) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0090*/                   IMAD.SHL.U32 R14, R9.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R17, R9, 0x2, R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 260
#         /*00b0*/                   IADD3 R10, P0, R14.reuse, c[0x0][0x188], RZ ;
#         /*00c0*/                   IADD3 R12, P1, R14, c[0x0][0x190], RZ ;
#         /*00d0*/                   IADD3.X R11, R17.reuse, c[0x0][0x18c], RZ, P0, !PT ;
#         /*00e0*/                   IADD3.X R13, R17, c[0x0][0x194], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*00f0*/                   IMAD.WIDE R10, R0, 0x8, R10 ;
#         /*0100*/                   IMAD.WIDE R12, R0, 0x8, R12 ;
#         /*0110*/                   LDG.E.64.SYS R8, [R10] ;
#         /*0120*/                   LDG.E.64.SYS R2, [R12] ;
#         /*0130*/                   LDG.E.64.SYS R4, [R10+0x200] ;
#         /*0140*/                   LDG.E.64.SYS R6, [R12+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0150*/                   IADD3 R14, P0, R14, c[0x0][0x180], RZ ;
#         /*0160*/                   IADD3.X R15, R17, c[0x0][0x184], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0170*/                   IMAD.WIDE R14, R0, 0x8, R14 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0180*/                   FFMA R3, R3, c[0x0][0x168], R9 ;
#         /*0190*/                   FFMA R2, R2, c[0x0][0x168], R8 ;
#         /*01a0*/                   FFMA R5, R7, c[0x0][0x168], R5 ;
#         /*01b0*/                   FFMA R4, R6, c[0x0][0x168], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01c0*/                   STG.E.64.SYS [R14], R2 ;
#         /*01d0*/                   STG.E.64.SYS [R14+0x200], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*01e0*/                   EXIT ;
# .L_3167:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*01f0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
#         /*0200*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0210*/                   BSSY B0, `(.L_3168) ;
#         /*0220*/               @P0 BRA `(.L_3169) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0230*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0240*/                   LEA.HI.X.SX32 R4, R0, R17, 0x1, P1 ;
#         /*0250*/                   LEA R2, P1, R3, c[0x0][0x188], 0x2 ;
#         /*0260*/                   LEA.HI.X R3, R3, c[0x0][0x18c], R4, 0x2, P1 ;
#         /*0270*/                   LDG.E.SYS R8, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0280*/                   IADD3 R4, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0290*/                   ISETP.GE.AND P1, PT, R4, R5, PT ;
#         /*02a0*/               @P1 BRA `(.L_3169) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02b0*/                   LDG.E.SYS R4, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02c0*/                   IADD3 R6, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02d0*/                   ISETP.GE.AND P1, PT, R6, R5, PT ;
#         /*02e0*/               @P1 BRA `(.L_3169) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02f0*/                   IADD3 R10, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0300*/                   LDG.E.SYS R7, [R2+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0310*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0320*/              @!P1 LDG.E.SYS R6, [R2+0x300] ;
# .L_3169:
#         /*0330*/                   BSYNC B0 ;
# .L_3168:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0340*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0350*/                   BSSY B0, `(.L_3170) ;
#         /*0360*/               @P0 BRA `(.L_3171) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0370*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0380*/                   LEA.HI.X.SX32 R10, R0, R17, 0x1, P1 ;
#         /*0390*/                   LEA R2, P1, R3, c[0x0][0x190], 0x2 ;
#         /*03a0*/                   LEA.HI.X R3, R3, c[0x0][0x194], R10, 0x2, P1 ;
#         /*03b0*/                   LDG.E.SYS R11, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*03c0*/                   IADD3 R10, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*03d0*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
#         /*03e0*/               @P1 BRA `(.L_3171) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*03f0*/                   LDG.E.SYS R13, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0400*/                   IADD3 R10, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0410*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
#         /*0420*/               @P1 BRA `(.L_3171) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0430*/                   IADD3 R10, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0440*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0450*/                   LDG.E.SYS R10, [R2+0x200] ;
#         /*0460*/              @!P1 LDG.E.SYS R15, [R2+0x300] ;
# .L_3171:
#         /*0470*/                   BSYNC B0 ;
# .L_3170:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0480*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0490*/                   IADD3 R9, P0, R9, R0, RZ ;
#         /*04a0*/                   FFMA R11, R11, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*04b0*/                   IADD3 R14, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*04c0*/                   LEA.HI.X.SX32 R12, R0, R17, 0x1, P0 ;
#         /*04d0*/                   LEA R2, P0, R9.reuse, c[0x0][0x180], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04e0*/                   ISETP.GE.AND P1, PT, R14, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*04f0*/                   LEA.HI.X R3, R9, c[0x0][0x184], R12, 0x2, P0 ;
#         /*0500*/                   STG.E.SYS [R2], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0510*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0520*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0530*/                   FFMA R13, R13, c[0x0][0x168], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0540*/                   ISETP.GE.AND P0, PT, R8, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0550*/                   STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0560*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0570*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0580*/                   FFMA R7, R10, c[0x0][0x168], R7 ;
#         /*0590*/                   FFMA R15, R15, c[0x0][0x168], R6 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*05a0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*05b0*/                   STG.E.SYS [R2+0x200], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*05c0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*05d0*/                   STG.E.SYS [R2+0x300], R15 ;
#         /*05e0*/                   EXIT ;
# .L_3172:
#         /*05f0*/                   BRA `(.L_3172);
# .L_40897:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<4, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40898 - _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R9, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R9, R9, 0x100, RZ ;
#         /*0050*/                   IADD3 R5, -R9, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0060*/                   SHF.R.S32.HI R17, RZ, 0x1f, R9 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*0070*/                   ISETP.GE.AND P0, PT, R5, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_3173) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0090*/                   IMAD.SHL.U32 R12, R9.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R17, R9, 0x2, R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 260
#         /*00b0*/                   IADD3 R8, P0, R12.reuse, c[0x0][0x188], RZ ;
#         /*00c0*/                   IADD3 R2, P1, R12, c[0x0][0x190], RZ ;
#         /*00d0*/                   IADD3.X R9, R17.reuse, c[0x0][0x18c], RZ, P0, !PT ;
#         /*00e0*/                   IADD3.X R3, R17, c[0x0][0x194], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*00f0*/                   IMAD.WIDE R8, R0, 0x10, R8 ;
#         /*0100*/                   IMAD.WIDE R2, R0, 0x10, R2 ;
#         /*0110*/                   LDG.E.128.SYS R8, [R8] ;
#         /*0120*/                   LDG.E.128.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0130*/                   IADD3 R12, P0, R12, c[0x0][0x180], RZ ;
#         /*0140*/                   IADD3.X R13, R17, c[0x0][0x184], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0150*/                   IMAD.WIDE R12, R0, 0x10, R12 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0160*/                   FFMA R7, R7, c[0x0][0x168], R11 ;
#         /*0170*/                   FFMA R6, R6, c[0x0][0x168], R10 ;
#         /*0180*/                   FFMA R5, R5, c[0x0][0x168], R9 ;
#         /*0190*/                   FFMA R4, R4, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01a0*/                   STG.E.128.SYS [R12], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*01b0*/                   EXIT ;
# .L_3173:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*01c0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
#         /*01d0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*01e0*/                   BSSY B0, `(.L_3174) ;
#         /*01f0*/               @P0 BRA `(.L_3175) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0200*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0210*/                   LEA.HI.X.SX32 R4, R0, R17, 0x1, P1 ;
#         /*0220*/                   LEA R2, P1, R3, c[0x0][0x188], 0x2 ;
#         /*0230*/                   LEA.HI.X R3, R3, c[0x0][0x18c], R4, 0x2, P1 ;
#         /*0240*/                   LDG.E.SYS R8, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0250*/                   IADD3 R4, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0260*/                   ISETP.GE.AND P1, PT, R4, R5, PT ;
#         /*0270*/               @P1 BRA `(.L_3175) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0280*/                   LDG.E.SYS R4, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0290*/                   IADD3 R6, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02a0*/                   ISETP.GE.AND P1, PT, R6, R5, PT ;
#         /*02b0*/               @P1 BRA `(.L_3175) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02c0*/                   IADD3 R10, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02d0*/                   LDG.E.SYS R7, [R2+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02e0*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02f0*/              @!P1 LDG.E.SYS R6, [R2+0x300] ;
# .L_3175:
#         /*0300*/                   BSYNC B0 ;
# .L_3174:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0310*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0320*/                   BSSY B0, `(.L_3176) ;
#         /*0330*/               @P0 BRA `(.L_3177) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0340*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0350*/                   LEA.HI.X.SX32 R10, R0, R17, 0x1, P1 ;
#         /*0360*/                   LEA R2, P1, R3, c[0x0][0x190], 0x2 ;
#         /*0370*/                   LEA.HI.X R3, R3, c[0x0][0x194], R10, 0x2, P1 ;
#         /*0380*/                   LDG.E.SYS R11, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0390*/                   IADD3 R10, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*03a0*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
#         /*03b0*/               @P1 BRA `(.L_3177) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*03c0*/                   LDG.E.SYS R13, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*03d0*/                   IADD3 R10, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*03e0*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
#         /*03f0*/               @P1 BRA `(.L_3177) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0400*/                   IADD3 R10, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0410*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0420*/                   LDG.E.SYS R10, [R2+0x200] ;
#         /*0430*/              @!P1 LDG.E.SYS R15, [R2+0x300] ;
# .L_3177:
#         /*0440*/                   BSYNC B0 ;
# .L_3176:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0450*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0460*/                   IADD3 R9, P0, R9, R0, RZ ;
#         /*0470*/                   FFMA R11, R11, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0480*/                   IADD3 R14, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0490*/                   LEA.HI.X.SX32 R12, R0, R17, 0x1, P0 ;
#         /*04a0*/                   LEA R2, P0, R9.reuse, c[0x0][0x180], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04b0*/                   ISETP.GE.AND P1, PT, R14, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*04c0*/                   LEA.HI.X R3, R9, c[0x0][0x184], R12, 0x2, P0 ;
#         /*04d0*/                   STG.E.SYS [R2], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04e0*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*04f0*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0500*/                   FFMA R13, R13, c[0x0][0x168], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0510*/                   ISETP.GE.AND P0, PT, R8, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0520*/                   STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0530*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0540*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0550*/                   FFMA R7, R10, c[0x0][0x168], R7 ;
#         /*0560*/                   FFMA R15, R15, c[0x0][0x168], R6 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0570*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0580*/                   STG.E.SYS [R2+0x200], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0590*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*05a0*/                   STG.E.SYS [R2+0x300], R15 ;
#         /*05b0*/                   EXIT ;
# .L_3178:
#         /*05c0*/                   BRA `(.L_3178);
#         /*05d0*/                   NOP;
#         /*05e0*/                   NOP;
#         /*05f0*/                   NOP;
# .L_40898:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<1, 64, 4, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#2}, at::detail::Array<char*, 2> >(int, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#2}, at::detail::Array<char*, 2>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=16"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,(.L_40899 - _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R0, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R11, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R0, R0, 0x100, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0050*/                   SHF.R.S32.HI R3, RZ, 0x1f, R11 ;
#         /*0060*/                   IADD3 R4, P0, R0, R11, RZ ;
#         /*0070*/                   LEA.HI.X.SX32 R3, R0, R3, 0x1, P0 ;
#         /*0080*/                   IMAD.SHL.U32 R2, R4, 0x4, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0090*/                   IADD3 R0, -R0, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*00a0*/                   SHF.L.U64.HI R3, R4, 0x2, R3 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*00b0*/                   ISETP.GE.AND P0, PT, R0, 0x100, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*00c0*/                   IADD3 R4, P1, R2.reuse, c[0x0][0x198], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*00d0*/                   IADD3 R2, P2, R2, c[0x0][0x190], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*00e0*/                   IADD3.X R5, R3.reuse, c[0x0][0x19c], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*00f0*/                   IADD3.X R3, R3, c[0x0][0x194], RZ, P2, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*0100*/              @!P0 BRA `(.L_3179) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*0110*/                   LDG.E.SYS R0, [R4] ;
#         /*0120*/                   LDG.E.SYS R6, [R4+0x100] ;
#         /*0130*/                   LDG.E.SYS R8, [R4+0x200] ;
#         /*0140*/                   LDG.E.SYS R10, [R4+0x300] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0150*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
#         /*0160*/                   FFMA R7, R13.reuse, c[0x0][0x178], R0 ;
#         /*0170*/                   FFMA R9, R13.reuse, c[0x0][0x178], R6 ;
#         /*0180*/                   FFMA R11, R13, c[0x0][0x178], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0190*/                   STG.E.SYS [R2], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*01a0*/                   FFMA R13, R13, c[0x0][0x178], R10 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01b0*/                   STG.E.SYS [R2+0x100], R9 ;
#         /*01c0*/                   STG.E.SYS [R2+0x200], R11 ;
#         /*01d0*/                   STG.E.SYS [R2+0x300], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*01e0*/                   EXIT ;
# .L_3179:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*01f0*/                   ISETP.GE.AND P0, PT, R11, R0, PT ;
#         /*0200*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0210*/                   BSSY B0, `(.L_3180) ;
#         /*0220*/               @P0 BRA `(.L_3181) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0230*/                   LDG.E.SYS R6, [R4] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0240*/                   IADD3 R7, R11, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0250*/                   ISETP.GE.AND P1, PT, R7, R0, PT ;
#         /*0260*/               @P1 BRA `(.L_3181) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0270*/                   LDG.E.SYS R7, [R4+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0280*/                   IADD3 R9, R11, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0290*/                   ISETP.GE.AND P1, PT, R9, R0, PT ;
#         /*02a0*/               @P1 BRA `(.L_3181) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02b0*/                   IADD3 R9, R11, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02c0*/                   LDG.E.SYS R8, [R4+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02d0*/                   ISETP.GE.AND P1, PT, R9, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02e0*/              @!P1 LDG.E.SYS R10, [R4+0x300] ;
# .L_3181:
#         /*02f0*/                   BSYNC B0 ;
# .L_3180:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0300*/                   IMAD.MOV.U32 R9, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0310*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0320*/                   IADD3 R13, R11, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0330*/                   FFMA R5, R9, c[0x0][0x178], R6 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0340*/                   ISETP.GE.AND P0, PT, R13, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0350*/                   STG.E.SYS [R2], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0360*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0370*/                   IADD3 R5, R11, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0380*/                   FFMA R7, R9, c[0x0][0x178], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0390*/                   ISETP.GE.AND P0, PT, R5, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*03a0*/                   STG.E.SYS [R2+0x100], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03b0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
# ...
#         /*0230*/                   LDG.E.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0240*/                   IADD3 R6, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0250*/                   ISETP.GE.AND P1, PT, R6, R7, PT ;
#         /*0260*/               @P1 BRA `(.L_3197) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0270*/                   LDG.E.SYS R6, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0280*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0290*/                   ISETP.GE.AND P1, PT, R8, R7, PT ;
#         /*02a0*/               @P1 BRA `(.L_3197) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02b0*/                   IADD3 R8, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02c0*/                   ISETP.GE.AND P1, PT, R8, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02d0*/                   LDG.E.SYS R8, [R2+0x200] ;
#         /*02e0*/              @!P1 LDG.E.SYS R9, [R2+0x300] ;
# .L_3197:
#         /*02f0*/                   BSYNC B0 ;
# .L_3196:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0300*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0310*/                   IADD3 R3, P0, R5, R0, RZ ;
#         /*0320*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0330*/                   IADD3 R12, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0340*/                   LEA.HI.X.SX32 R10, R0, R11, 0x1, P0 ;
#         /*0350*/                   FFMA R5, R4, R13, c[0x0][0x178] ;
#         /*0360*/                   LEA R2, P0, R3.reuse, c[0x0][0x190], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0370*/                   ISETP.GE.AND P1, PT, R12, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0380*/                   LEA.HI.X R3, R3, c[0x0][0x194], R10, 0x2, P0 ;
#         /*0390*/                   STG.E.SYS [R2], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03a0*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*03b0*/                   IADD3 R4, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*03c0*/                   FFMA R5, R6, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03d0*/                   ISETP.GE.AND P0, PT, R4, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*03e0*/                   STG.E.SYS [R2+0x100], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03f0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0400*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0410*/                   FFMA R5, R8, R13.reuse, c[0x0][0x178] ;
#         /*0420*/                   FFMA R9, R9, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0430*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0440*/                   STG.E.SYS [R2+0x200], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0450*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0460*/                   STG.E.SYS [R2+0x300], R9 ;
#         /*0470*/                   EXIT ;
# .L_3198:
#         /*0480*/                   BRA `(.L_3198);
#         /*0490*/                   NOP;
#         /*04a0*/                   NOP;
#         /*04b0*/                   NOP;
#         /*04c0*/                   NOP;
#         /*04d0*/                   NOP;
#         /*04e0*/                   NOP;
#         /*04f0*/                   NOP;
# .L_40903:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<4, 64, 4, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#1}, at::detail::Array<char*, 2>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=16"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,(.L_40904 - _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R5, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R5, R5, 0x100, RZ ;
#         /*0050*/                   IADD3 R7, -R5, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0060*/                   SHF.R.S32.HI R11, RZ, 0x1f, R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*0070*/                   ISETP.GE.AND P0, PT, R7, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_3199) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 260
#         /*0090*/                   IMAD.SHL.U32 R8, R5.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R11, R5, 0x2, R11 ;
#         /*00b0*/                   IADD3 R2, P0, R8, c[0x0][0x198], RZ ;
#         /*00c0*/                   IADD3.X R3, R11, c[0x0][0x19c], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*00d0*/                   IMAD.WIDE R2, R0, 0x10, R2 ;
#         /*00e0*/                   LDG.E.128.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*00f0*/                   IADD3 R8, P0, R8, c[0x0][0x190], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0100*/                   IMAD.MOV.U32 R10, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0110*/                   IADD3.X R9, R11, c[0x0][0x194], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0120*/                   IMAD.WIDE R8, R0, 0x10, R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0130*/                   FFMA R7, R7, R10.reuse, c[0x0][0x178] ;
#         /*0140*/                   FFMA R6, R6, R10.reuse, c[0x0][0x178] ;
#         /*0150*/                   FFMA R5, R5, R10.reuse, c[0x0][0x178] ;
#         /*0160*/                   FFMA R4, R4, R10, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0170*/                   STG.E.128.SYS [R8], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*0180*/                   EXIT ;
# .L_3199:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0190*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
#         /*01a0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*01b0*/                   BSSY B0, `(.L_3200) ;
#         /*01c0*/               @P0 BRA `(.L_3201) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*01d0*/                   IADD3 R3, P1, R5, R0, RZ ;
#         /*01e0*/                   LEA.HI.X.SX32 R4, R0, R11, 0x1, P1 ;
#         /*01f0*/                   LEA R2, P1, R3, c[0x0][0x198], 0x2 ;
#         /*0200*/                   LEA.HI.X R3, R3, c[0x0][0x19c], R4, 0x2, P1 ;
#         /*0210*/                   LDG.E.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0220*/                   IADD3 R6, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0230*/                   ISETP.GE.AND P1, PT, R6, R7, PT ;
#         /*0240*/               @P1 BRA `(.L_3201) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0250*/                   LDG.E.SYS R6, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0260*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0270*/                   ISETP.GE.AND P1, PT, R8, R7, PT ;
#         /*0280*/               @P1 BRA `(.L_3201) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0290*/                   IADD3 R8, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02a0*/                   ISETP.GE.AND P1, PT, R8, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02b0*/                   LDG.E.SYS R8, [R2+0x200] ;
#         /*02c0*/              @!P1 LDG.E.SYS R9, [R2+0x300] ;
# .L_3201:
#         /*02d0*/                   BSYNC B0 ;
# .L_3200:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*02e0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*02f0*/                   IADD3 R3, P0, R5, R0, RZ ;
#         /*0300*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0310*/                   IADD3 R12, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0320*/                   LEA.HI.X.SX32 R10, R0, R11, 0x1, P0 ;
#         /*0330*/                   FFMA R5, R4, R13, c[0x0][0x178] ;
#         /*0340*/                   LEA R2, P0, R3.reuse, c[0x0][0x190], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0350*/                   ISETP.GE.AND P1, PT, R12, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0360*/                   LEA.HI.X R3, R3, c[0x0][0x194], R10, 0x2, P0 ;
#         /*0370*/                   STG.E.SYS [R2], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0380*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0390*/                   IADD3 R4, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*03a0*/                   FFMA R5, R6, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03b0*/                   ISETP.GE.AND P0, PT, R4, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*03c0*/                   STG.E.SYS [R2+0x100], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03d0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*03e0*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*03f0*/                   FFMA R5, R8, R13.reuse, c[0x0][0x178] ;
#         /*0400*/                   FFMA R9, R9, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0410*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0420*/                   STG.E.SYS [R2+0x200], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0430*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0440*/                   STG.E.SYS [R2+0x300], R9 ;
#         /*0450*/                   EXIT ;
# .L_3202:
#         /*0460*/                   BRA `(.L_3202);
#         /*0470*/                   NOP;
# .L_40904:
