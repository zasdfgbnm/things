# %% [markdown]
# # Before

# %%
import torch
print(torch.__version__)
print()

for i in range(1000):
    torch.arange(10000, device='cuda')

def benchmark(dtype, i):
    numel = 2 ** i
    a = torch.zeros(numel, device='cuda', dtype=dtype)
    torch.cuda.synchronize()
    # %timeit a.sum(dtype=dtype); torch.cuda.synchronize()

for dtype in [torch.int8, torch.half, torch.float, torch.double]:
    print(dtype)
    for i in range(18, 30):
        benchmark(dtype, i)
    print()
# Out:
# 1.6.0a0+2f5b523
#
# torch.int8
# 17.4 µs ± 409 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 17.1 µs ± 453 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 18.2 µs ± 352 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 21.5 µs ± 1.36 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 26.9 µs ± 1.07 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 47 µs ± 2.14 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 73.7 µs ± 1.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 143 µs ± 9.4 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 261 µs ± 13.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 508 µs ± 12.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1 ms ± 75.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.88 ms ± 1.58 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
#
# torch.float16
# 17.9 µs ± 1.1 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 18.6 µs ± 2.77 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 17.9 µs ± 411 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 20.2 µs ± 462 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 37.2 µs ± 1.75 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 50.9 µs ± 769 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 88.6 µs ± 4.15 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 152 µs ± 4.54 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 288 µs ± 8.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 570 µs ± 32.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.06 ms ± 7.04 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.05 ms ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# torch.float32
# 17.6 µs ± 646 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 17 µs ± 87.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 18.1 µs ± 82 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 31.4 µs ± 29.6 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 45.9 µs ± 21.2 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 75.1 µs ± 36.1 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 133 µs ± 578 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 250 µs ± 2.64 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 481 µs ± 279 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 945 µs ± 1.13 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.89 ms ± 42.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.74 ms ± 30.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# torch.float64
# 21.1 µs ± 253 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 21.5 µs ± 236 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 35.3 µs ± 26 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 52.1 µs ± 12.8 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 80.6 µs ± 42.6 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 139 µs ± 108 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 255 µs ± 2.63 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 485 µs ± 57.5 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 946 µs ± 197 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.87 ms ± 958 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 3.71 ms ± 797 ns per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.42 ms ± 12.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # After

# %%
import torch
print(torch.__version__)
print()

for i in range(1000):
    torch.arange(10000, device='cuda')

def benchmark(dtype, i):
    numel = 2 ** i
    a = torch.zeros(numel, device='cuda', dtype=dtype)
    torch.cuda.synchronize()
    # %timeit a.sum(dtype=dtype); torch.cuda.synchronize()

for dtype in [torch.int8, torch.half, torch.float, torch.double]:
    print(dtype)
    for i in range(18, 30):
        benchmark(dtype, i)
    print()
# Out:
# 1.6.0a0+80b01ba
#
# torch.int8
# 26.8 µs ± 358 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 28.3 µs ± 411 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 58.9 µs ± 234 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 98.2 µs ± 301 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 174 µs ± 343 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 326 µs ± 1.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 631 µs ± 2.86 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.24 ms ± 5.82 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.51 ms ± 30 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5 ms ± 32.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.98 ms ± 52.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20.1 ms ± 239 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# torch.float16
# 18.3 µs ± 43.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 18.6 µs ± 196 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 19.3 µs ± 97 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 20.5 µs ± 419 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 34.8 µs ± 345 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 50.9 µs ± 224 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 83.6 µs ± 174 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 149 µs ± 428 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 279 µs ± 1.69 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 541 µs ± 2.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.06 ms ± 3.79 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.09 ms ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# torch.float32
# 18.6 µs ± 250 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 18.8 µs ± 40.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 20.5 µs ± 198 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 34.1 µs ± 263 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 50.2 µs ± 352 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 82.4 µs ± 238 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 148 µs ± 1.38 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 276 µs ± 2.86 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 531 µs ± 2.08 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.05 ms ± 4.51 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.12 ms ± 67.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.16 ms ± 20.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# torch.float64
# 23.5 µs ± 394 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 24.5 µs ± 676 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 40.6 µs ± 1.29 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 55.7 µs ± 220 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 87.9 µs ± 356 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 153 µs ± 477 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 279 µs ± 3.09 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 541 µs ± 1.38 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.05 ms ± 6.03 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 2.12 ms ± 66.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.19 ms ± 23 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.37 ms ± 30.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
