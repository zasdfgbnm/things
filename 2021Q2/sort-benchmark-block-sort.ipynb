# %%
import torch
import itertools

for i in range(1000):
    torch.arange(100000, device='cuda')

def run50_sync(f):
    for _ in range(50):
        f()
    torch.cuda.synchronize()

# %% [markdown]
# # block sort

# %%
for i, j in itertools.product([1, 64, 512, 2048], repeat=2):
    print(i,j)
    t = torch.randn(i, j, device='cuda')
    torch.cuda.synchronize()
    # %timeit run50_sync(lambda: torch.sort(t))
    torch.cuda.synchronize()
    # %timeit run50_sync(lambda: torch.sort(t, dim=0))
    print()
# Out:
# 1 1
# 3.69 ms ± 8.12 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.92 ms ± 51.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 64
# 3.8 ms ± 4.85 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.3 ms ± 103 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 512
# 3.83 ms ± 18.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.4 ms ± 9.98 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 2048
# 3.82 ms ± 14 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.3 ms ± 36.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 1
# 5.9 ms ± 32.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.91 ms ± 62.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 64
# 5.74 ms ± 11.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.5 ms ± 115 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 512
# 5.82 ms ± 83.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.7 ms ± 14.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 2048
# 5.87 ms ± 19.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.5 ms ± 17.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 1
# 5.9 ms ± 8.32 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.84 ms ± 55.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 64
# 5.92 ms ± 48.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.5 ms ± 131 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 512
# 5.87 ms ± 91.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.5 ms ± 113 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 2048
# 6.45 ms ± 37.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.6 ms ± 6.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 1
# 5.88 ms ± 83.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.77 ms ± 11.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 64
# 5.88 ms ± 92.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.6 ms ± 108 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 512
# 6.11 ms ± 8.71 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.7 ms ± 61.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 2048
# 21.5 ms ± 277 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 34.8 ms ± 255 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # bitonic sort

# %%
for i, j in itertools.product([1, 64, 512, 2048], repeat=2):
    print(i,j)
    t = torch.randn(i, j, device='cuda')
    torch.cuda.synchronize()
    # %timeit run50_sync(lambda: torch.sort(t))
    torch.cuda.synchronize()
    # %timeit run50_sync(lambda: torch.sort(t, dim=0))
    print()
# Out:
# 1 1
# 5.47 ms ± 12.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.54 ms ± 9.94 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 64
# 5.7 ms ± 28.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.84 ms ± 31.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 512
# 5.73 ms ± 11.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.8 ms ± 68.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 2048
# 5.75 ms ± 47.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.7 ms ± 10.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 1
# 5.6 ms ± 9.63 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.77 ms ± 26.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 64
# 5.94 ms ± 32.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.05 ms ± 37.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 512
# 5.97 ms ± 16.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.88 ms ± 3.39 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 2048
# 5.99 ms ± 32 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.06 ms ± 3.95 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 1
# 5.66 ms ± 68.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.62 ms ± 6.99 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 64
# 5.88 ms ± 71.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.89 ms ± 10.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 512
# 5.92 ms ± 15.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.08 ms ± 20.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 2048
# 15.6 ms ± 68.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.5 ms ± 112 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 1
# 5.7 ms ± 64.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.66 ms ± 6.94 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 64
# 5.86 ms ± 14.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.97 ms ± 16.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 512
# 16.3 ms ± 75.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20.1 ms ± 101 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 2048
# 55 ms ± 350 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 71.2 ms ± 252 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # segment sort

# %%
for i, j in itertools.product([1, 64, 512, 2048], repeat=2):
    print(i,j)
    t = torch.randn(i, j, device='cuda')
    torch.cuda.synchronize()
    # %timeit run50_sync(lambda: torch.sort(t))
    torch.cuda.synchronize()
    # %timeit run50_sync(lambda: torch.sort(t, dim=0))
    print()
# Out:
# 1 1
# 6.95 ms ± 89.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.18 ms ± 9.14 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 64
# 7.12 ms ± 6.08 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 14.7 ms ± 213 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 512
# 7.1 ms ± 86.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 15.2 ms ± 28.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 1 2048
# 7.19 ms ± 117 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 28.3 ms ± 147 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# 64 1
# 9.24 ms ± 114 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.17 ms ± 12.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 64
# 9.08 ms ± 120 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 15 ms ± 62.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 512
# 9.12 ms ± 130 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 15.2 ms ± 27.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 64 2048
# 9.1 ms ± 53.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 28.9 ms ± 121 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# 512 1
# 9.36 ms ± 27.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.01 ms ± 7.66 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 64
# 9.4 ms ± 81.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 15.6 ms ± 189 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 512
# 9.75 ms ± 71.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 15.6 ms ± 176 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 512 2048
# 17.3 ms ± 109 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 35 ms ± 540 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# 2048 1
# 27.5 ms ± 217 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 7.08 ms ± 67.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 64
# 28.2 ms ± 341 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 15.1 ms ± 15.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
#
# 2048 512
# 31.1 ms ± 274 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 20.6 ms ± 176 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# 2048 2048
# 55.5 ms ± 404 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 69.4 ms ± 1.31 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
