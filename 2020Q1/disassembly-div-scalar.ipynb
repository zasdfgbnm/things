# %%
import disasm

def filter_(demangled_symbol, code):
    return demangled_symbol == 'void at::native::modern::elementwise_kernel<4, at::native::div_kernel_cuda(at::TensorIterator&)::{lambda()#1}::operator()() const::{lambda()#5}::operator()() const::{lambda(c10::Half)#1}, at::detail::Array<char*, 2> >(int, at::native::div_kernel_cuda(at::TensorIterator&)::{lambda()#1}::operator()() const::{lambda()#5}::operator()() const::{lambda(c10::Half)#1}, at::detail::Array<char*, 2>)'

disasm.run('BinaryArithmeticKernel.sm_70.cubin', filter_)
# Out:
# 1.5.0a0+e1c6f93
# e1c6f93f14be9cb62bc3c989cad3af3f6a059e27
#
# Running:
# rm -rf BinaryArithmeticKernel.sm_70.cubin; cuobjdump -xelf BinaryArithmeticKernel.sm_70.cubin /home/xgao/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<4, at::native::div_kernel_cuda(at::TensorIterator&)::{lambda()#1}::operator()() const::{lambda()#5}::operator()() const::{lambda(c10::Half)#1}, at::detail::Array<char*, 2> >(int, at::native::div_kernel_cuda(at::TensorIterator&)::{lambda()#1}::operator()() const::{lambda()#5}::operator()() const::{lambda(c10::Half)#1}, at::detail::Array<char*, 2>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi4EZZZNS0_15div_kernel_cudaERNS_14TensorIteratorEENKUlvE_clEvENKUlvE3_clEvEUlN3c104HalfEE_NS_6detail5ArrayIPcLi2EEEEEviT0_T1_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=19"
# 	.align	128
# ...
