# %% [markdown]
# # Old code

# %%
import disasm

def filter_(demangled_symbol, code):
    ret = True
    ret &= 'add_kernel' in demangled_symbol             # add kernel
    ret &= 'lambda(float, float)' in demangled_symbol   # dtype = float
    ret &= 'TypeCast.h' not in code                     # no dynamic casting
    ret &= 'OffsetCalculator.cuh' not in code           # trivial 1d
    return ret

disasm.run('BinaryArithmeticKernel.sm_70.cubin', filter_)
# Out:
# 1.5.0a0+dedd16b
# dedd16b4181cae81e37e978cd3bf24c1ba35ca05
#
# Running:
# rm -rf BinaryArithmeticKernel.sm_70.cubin; cuobjdump -xelf BinaryArithmeticKernel.sm_70.cubin /home/xgao/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so
#
# **Symbol:**
# void at::native::elementwise_kernel<512, 1, at::native::gpu_kernel_impl<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(int)#2}>(int, at::native::gpu_kernel_impl<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(int)#2})
#
# **ASM:**
#
# 	.section	.text._ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS4_RKT_EUliE0_EEviT1_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=12"
# 	.align	128
#         .global         _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS4_RKT_EUliE0_EEviT1_
#         .type           _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS4_RKT_EUliE0_EEviT1_,@function
#         .size           _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS4_RKT_EUliE0_EEviT1_,(.L_29063 - _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS4_RKT_EUliE0_EEviT1_)
#         .other          _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS4_RKT_EUliE0_EEviT1_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS4_RKT_EUliE0_EEviT1_:
# .text._ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS4_RKT_EUliE0_EEviT1_:
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 71
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 73
#         /*0030*/                   S2R R3, SR_CTAID.X ;
#         /*0040*/                   IMAD R0, R3, 0x200, R0 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 76
#         /*0050*/                   ISETP.GE.AND P0, PT, R0, c[0x0][0x160], PT ;
#         /*0060*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 110
#         /*0070*/                   IMAD R3, R0.reuse, c[0x0][0x194], RZ ;
#         /*0080*/                   IMAD R6, R0, c[0x0][0x198], RZ ;
#         /*0090*/                   IADD3 R4, P0, R3.reuse, c[0x0][0x178], RZ ;
#         /*00a0*/                   IADD3 R2, P1, R6.reuse, c[0x0][0x180], RZ ;
#         /*00b0*/                   LEA.HI.X.SX32 R5, R3, c[0x0][0x17c], 0x1, P0 ;
#         /*00c0*/                   LEA.HI.X.SX32 R3, R6, c[0x0][0x184], 0x1, P1 ;
#         /*00d0*/                   LDG.E.SYS R5, [R4] ;
#         /*00e0*/                   LDG.E.SYS R2, [R2] ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 77
#         /*00f0*/                   IMAD R0, R0, c[0x0][0x190], RZ ;
#         /*0100*/                   IADD3 R6, P0, R0, c[0x0][0x170], RZ ;
#         /*0110*/                   LEA.HI.X.SX32 R7, R0, c[0x0][0x174], 0x1, P0 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 110
#         /*0120*/                   FFMA R9, R2, c[0x0][0x1a0], R5 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 170
#         /*0130*/                   STG.E.SYS [R6], R9 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 81
#         /*0140*/                   EXIT ;
# .L_16826:
#         /*0150*/                   BRA `(.L_16826);
#         /*0160*/                   NOP;
#         /*0170*/                   NOP;
# .L_29063:
#
# **Symbol:**
# void at::native::elementwise_kernel<512, 1, at::native::gpu_kernel_impl<at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#2}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1})::{lambda(int)#2}>(int, at::native::gpu_kernel_impl<at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#2}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1})::{lambda(int)#2})
#
# **ASM:**
#
# 	.section	.text._ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_EEvS5_SD_EUliE0_EEviT1_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=10"
# 	.align	128
#         .global         _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_EEvS5_SD_EUliE0_EEviT1_
#         .type           _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_EEvS5_SD_EUliE0_EEviT1_,@function
#         .size           _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_EEvS5_SD_EUliE0_EEviT1_,(.L_29067 - _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_EEvS5_SD_EUliE0_EEviT1_)
#         .other          _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_EEvS5_SD_EUliE0_EEviT1_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_EEvS5_SD_EUliE0_EEviT1_:
# .text._ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_EEvS5_SD_EUliE0_EEviT1_:
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 73
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R0, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 71
#         /*0030*/                   S2R R3, SR_TID.X ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 73
#         /*0040*/                   LEA R0, R0, R3, 0x9 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 76
#         /*0050*/                   ISETP.GE.AND P0, PT, R0, c[0x0][0x160], PT ;
#         /*0060*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 110
#         /*0070*/                   IMAD R3, R0, c[0x0][0x184], RZ ;
#         /*0080*/                   IADD3 R2, P0, R3, c[0x0][0x178], RZ ;
#         /*0090*/                   LEA.HI.X.SX32 R3, R3, c[0x0][0x17c], 0x1, P0 ;
#         /*00a0*/                   LDG.E.SYS R2, [R2] ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 77
#         /*00b0*/                   IMAD R0, R0, c[0x0][0x180], RZ ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 110
#         /*00c0*/                   IMAD.MOV.U32 R7, RZ, RZ, c[0x0][0x190] ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 77
#         /*00d0*/                   IADD3 R4, P0, R0, c[0x0][0x170], RZ ;
#         /*00e0*/                   LEA.HI.X.SX32 R5, R0, c[0x0][0x174], 0x1, P0 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 110
#         /*00f0*/                   FFMA R7, R7, c[0x0][0x1a0], R2 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 170
#         /*0100*/                   STG.E.SYS [R4], R7 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 81
#         /*0110*/                   EXIT ;
# .L_16980:
#         /*0120*/                   BRA `(.L_16980);
#         /*0130*/                   NOP;
#         /*0140*/                   NOP;
#         /*0150*/                   NOP;
#         /*0160*/                   NOP;
#         /*0170*/                   NOP;
# .L_29067:
#
# **Symbol:**
# void at::native::elementwise_kernel<512, 1, at::native::gpu_kernel_impl<at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1})::{lambda(int)#2}>(int, at::native::gpu_kernel_impl<at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1})::{lambda(int)#2})
#
# **ASM:**
#
# 	.section	.text._ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_EEvS5_SD_EUliE0_EEviT1_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=10"
# 	.align	128
#         .global         _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_EEvS5_SD_EUliE0_EEviT1_
#         .type           _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_EEvS5_SD_EUliE0_EEviT1_,@function
#         .size           _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_EEvS5_SD_EUliE0_EEviT1_,(.L_29071 - _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_EEvS5_SD_EUliE0_EEviT1_)
#         .other          _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_EEvS5_SD_EUliE0_EEviT1_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_EEvS5_SD_EUliE0_EEviT1_:
# .text._ZN2at6native18elementwise_kernelILi512ELi1EZNS0_15gpu_kernel_implIZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_EEvS5_SD_EUliE0_EEviT1_:
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 71
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 73
#         /*0030*/                   S2R R3, SR_CTAID.X ;
#         /*0040*/                   LEA R0, R3, R0, 0x9 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 76
#         /*0050*/                   ISETP.GE.AND P0, PT, R0, c[0x0][0x160], PT ;
#         /*0060*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 110
#         /*0070*/                   IMAD R3, R0, c[0x0][0x184], RZ ;
#         /*0080*/                   IADD3 R2, P0, R3, c[0x0][0x178], RZ ;
#         /*0090*/                   LEA.HI.X.SX32 R3, R3, c[0x0][0x17c], 0x1, P0 ;
#         /*00a0*/                   LDG.E.SYS R2, [R2] ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 77
#         /*00b0*/                   IMAD R0, R0, c[0x0][0x180], RZ ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 110
#         /*00c0*/                   IMAD.MOV.U32 R7, RZ, RZ, c[0x0][0x190] ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 77
#         /*00d0*/                   IADD3 R4, P0, R0, c[0x0][0x170], RZ ;
#         /*00e0*/                   LEA.HI.X.SX32 R5, R0, c[0x0][0x174], 0x1, P0 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 110
#         /*00f0*/                   FFMA R7, R2, R7, c[0x0][0x1a0] ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 170
#         /*0100*/                   STG.E.SYS [R4], R7 ;
# 	//## File "/home/xgao/pytorch-master/aten/src/ATen/native/cuda/Loops.cuh", line 81
#         /*0110*/                   EXIT ;
# .L_17122:
#         /*0120*/                   BRA `(.L_17122);
#         /*0130*/                   NOP;
#         /*0140*/                   NOP;
#         /*0150*/                   NOP;
#         /*0160*/                   NOP;
#         /*0170*/                   NOP;
# .L_29071:

# %% [markdown]
# # New code

# %%
import disasm

def filter_(demangled_symbol, code):
    ret = True
    ret &= 'modern' in demangled_symbol                 # new code
    ret &= 'add_kernel' in demangled_symbol             # add kernel
    ret &= 'lambda(float, float)' in demangled_symbol   # dtype = float
    ret &= 'TypeCast.h' not in code                     # no dynamic casting
    ret &= 'OffsetCalculator.cuh' not in code           # trivial 1d
    return ret

disasm.run('BinaryArithmeticKernel.sm_70.cubin', filter_)
# Out:
# 1.5.0a0+b141ee2
# b141ee2d2536459c1695ef5050faadce52a72686
#
# Running:
# rm -rf BinaryArithmeticKernel.sm_70.cubin; cuobjdump -xelf BinaryArithmeticKernel.sm_70.cubin /home/xgao/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<1, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40896 - _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R2, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R9, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R2, R2, 0x100, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0050*/                   SHF.R.S32.HI R3, RZ, 0x1f, R9 ;
#         /*0060*/                   IADD3 R16, P0, R2.reuse, R9, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0070*/                   IADD3 R0, -R2.reuse, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0080*/                   LEA.HI.X.SX32 R3, R2, R3, 0x1, P0 ;
#         /*0090*/                   IMAD.SHL.U32 R2, R16, 0x4, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*00a0*/                   ISETP.GE.AND P0, PT, R0, 0x100, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*00b0*/                   SHF.L.U64.HI R16, R16, 0x2, R3 ;
#         /*00c0*/                   IADD3 R6, P1, R2, c[0x0][0x188], RZ ;
#         /*00d0*/                   IADD3 R4, P2, R2, c[0x0][0x190], RZ ;
#         /*00e0*/                   IADD3.X R7, R16.reuse, c[0x0][0x18c], RZ, P1, !PT ;
#         /*00f0*/                   IADD3.X R5, R16, c[0x0][0x194], RZ, P2, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*0100*/               @P0 LDG.E.SYS R3, [R6] ;
#         /*0110*/               @P0 LDG.E.SYS R8, [R4] ;
#         /*0120*/               @P0 LDG.E.SYS R10, [R4+0x100] ;
#         /*0130*/               @P0 LDG.E.SYS R13, [R6+0x100] ;
#         /*0140*/               @P0 LDG.E.SYS R12, [R4+0x200] ;
#         /*0150*/               @P0 LDG.E.SYS R15, [R6+0x200] ;
#         /*0160*/               @P0 LDG.E.SYS R14, [R4+0x300] ;
#         /*0170*/               @P0 LDG.E.SYS R17, [R6+0x300] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0180*/                   IADD3 R2, P1, R2, c[0x0][0x180], RZ ;
#         /*0190*/               @P0 FFMA R11, R8, c[0x0][0x168], R3 ;
#         /*01a0*/                   IADD3.X R3, R16, c[0x0][0x184], RZ, P1, !PT ;
#         /*01b0*/               @P0 FFMA R13, R10, c[0x0][0x168], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01c0*/               @P0 STG.E.SYS [R2], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*01d0*/               @P0 FFMA R15, R12, c[0x0][0x168], R15 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01e0*/               @P0 STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*01f0*/               @P0 FFMA R17, R14, c[0x0][0x168], R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0200*/               @P0 STG.E.SYS [R2+0x200], R15 ;
#         /*0210*/               @P0 STG.E.SYS [R2+0x300], R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*0220*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0230*/                   ISETP.GE.AND P0, PT, R9, R0, PT ;
#         /*0240*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0250*/                   BSSY B0, `(.L_3162) ;
#         /*0260*/               @P0 BRA `(.L_3163) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0270*/                   LDG.E.SYS R8, [R6] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0280*/                   IADD3 R11, R9, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0290*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
#         /*02a0*/               @P1 BRA `(.L_3163) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02b0*/                   LDG.E.SYS R10, [R6+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02c0*/                   IADD3 R11, R9, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02d0*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
#         /*02e0*/               @P1 BRA `(.L_3163) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02f0*/                   IADD3 R11, R9, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0300*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0310*/                   LDG.E.SYS R11, [R6+0x200] ;
#         /*0320*/              @!P1 LDG.E.SYS R12, [R6+0x300] ;
# .L_3163:
#         /*0330*/                   BSYNC B0 ;
# .L_3162:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0340*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0350*/                   BSSY B0, `(.L_3164) ;
#         /*0360*/               @P0 BRA `(.L_3165) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0370*/                   LDG.E.SYS R7, [R4] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0380*/                   IADD3 R13, R9, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0390*/                   ISETP.GE.AND P1, PT, R13, R0, PT ;
#         /*03a0*/               @P1 BRA `(.L_3165) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*03b0*/                   LDG.E.SYS R13, [R4+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*03c0*/                   IADD3 R15, R9, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*03d0*/                   ISETP.GE.AND P1, PT, R15, R0, PT ;
#         /*03e0*/               @P1 BRA `(.L_3165) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*03f0*/                   IADD3 R17, R9, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0400*/                   LDG.E.SYS R6, [R4+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0410*/                   ISETP.GE.AND P1, PT, R17, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0420*/              @!P1 LDG.E.SYS R15, [R4+0x300] ;
# .L_3165:
#         /*0430*/                   BSYNC B0 ;
# .L_3164:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0440*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0450*/                   IADD3 R5, R9, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0460*/                   FFMA R7, R7, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0470*/                   ISETP.GE.AND P0, PT, R5, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0480*/                   STG.E.SYS [R2], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0490*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*04a0*/                   IADD3 R5, R9, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*04b0*/                   FFMA R13, R13, c[0x0][0x168], R10 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04c0*/                   ISETP.GE.AND P0, PT, R5, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*04d0*/                   STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04e0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*04f0*/                   IADD3 R9, R9, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0500*/                   FFMA R11, R6, c[0x0][0x168], R11 ;
#         /*0510*/                   FFMA R15, R15, c[0x0][0x168], R12 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0520*/                   ISETP.GE.AND P0, PT, R9, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0530*/                   STG.E.SYS [R2+0x200], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0540*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0550*/                   STG.E.SYS [R2+0x300], R15 ;
#         /*0560*/                   EXIT ;
# .L_3166:
#         /*0570*/                   BRA `(.L_3166);
# .L_40896:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<2, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40897 - _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R9, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R9, R9, 0x100, RZ ;
#         /*0050*/                   IADD3 R5, -R9, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0060*/                   SHF.R.S32.HI R17, RZ, 0x1f, R9 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*0070*/                   ISETP.GE.AND P0, PT, R5, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_3167) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0090*/                   IMAD.SHL.U32 R14, R9.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R17, R9, 0x2, R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 260
#         /*00b0*/                   IADD3 R10, P0, R14.reuse, c[0x0][0x188], RZ ;
#         /*00c0*/                   IADD3 R12, P1, R14, c[0x0][0x190], RZ ;
#         /*00d0*/                   IADD3.X R11, R17.reuse, c[0x0][0x18c], RZ, P0, !PT ;
#         /*00e0*/                   IADD3.X R13, R17, c[0x0][0x194], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*00f0*/                   IMAD.WIDE R10, R0, 0x8, R10 ;
#         /*0100*/                   IMAD.WIDE R12, R0, 0x8, R12 ;
#         /*0110*/                   LDG.E.64.SYS R8, [R10] ;
#         /*0120*/                   LDG.E.64.SYS R2, [R12] ;
#         /*0130*/                   LDG.E.64.SYS R4, [R10+0x200] ;
#         /*0140*/                   LDG.E.64.SYS R6, [R12+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0150*/                   IADD3 R14, P0, R14, c[0x0][0x180], RZ ;
#         /*0160*/                   IADD3.X R15, R17, c[0x0][0x184], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0170*/                   IMAD.WIDE R14, R0, 0x8, R14 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0180*/                   FFMA R3, R3, c[0x0][0x168], R9 ;
#         /*0190*/                   FFMA R2, R2, c[0x0][0x168], R8 ;
#         /*01a0*/                   FFMA R5, R7, c[0x0][0x168], R5 ;
#         /*01b0*/                   FFMA R4, R6, c[0x0][0x168], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01c0*/                   STG.E.64.SYS [R14], R2 ;
#         /*01d0*/                   STG.E.64.SYS [R14+0x200], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*01e0*/                   EXIT ;
# .L_3167:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*01f0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
#         /*0200*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0210*/                   BSSY B0, `(.L_3168) ;
#         /*0220*/               @P0 BRA `(.L_3169) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0230*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0240*/                   LEA.HI.X.SX32 R4, R0, R17, 0x1, P1 ;
#         /*0250*/                   LEA R2, P1, R3, c[0x0][0x188], 0x2 ;
#         /*0260*/                   LEA.HI.X R3, R3, c[0x0][0x18c], R4, 0x2, P1 ;
#         /*0270*/                   LDG.E.SYS R8, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0280*/                   IADD3 R4, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0290*/                   ISETP.GE.AND P1, PT, R4, R5, PT ;
#         /*02a0*/               @P1 BRA `(.L_3169) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02b0*/                   LDG.E.SYS R4, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02c0*/                   IADD3 R6, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02d0*/                   ISETP.GE.AND P1, PT, R6, R5, PT ;
#         /*02e0*/               @P1 BRA `(.L_3169) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02f0*/                   IADD3 R10, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0300*/                   LDG.E.SYS R7, [R2+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0310*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0320*/              @!P1 LDG.E.SYS R6, [R2+0x300] ;
# .L_3169:
#         /*0330*/                   BSYNC B0 ;
# .L_3168:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0340*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0350*/                   BSSY B0, `(.L_3170) ;
#         /*0360*/               @P0 BRA `(.L_3171) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0370*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0380*/                   LEA.HI.X.SX32 R10, R0, R17, 0x1, P1 ;
#         /*0390*/                   LEA R2, P1, R3, c[0x0][0x190], 0x2 ;
#         /*03a0*/                   LEA.HI.X R3, R3, c[0x0][0x194], R10, 0x2, P1 ;
#         /*03b0*/                   LDG.E.SYS R11, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*03c0*/                   IADD3 R10, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*03d0*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
#         /*03e0*/               @P1 BRA `(.L_3171) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*03f0*/                   LDG.E.SYS R13, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0400*/                   IADD3 R10, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0410*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
#         /*0420*/               @P1 BRA `(.L_3171) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0430*/                   IADD3 R10, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0440*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0450*/                   LDG.E.SYS R10, [R2+0x200] ;
#         /*0460*/              @!P1 LDG.E.SYS R15, [R2+0x300] ;
# .L_3171:
#         /*0470*/                   BSYNC B0 ;
# .L_3170:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0480*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0490*/                   IADD3 R9, P0, R9, R0, RZ ;
#         /*04a0*/                   FFMA R11, R11, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*04b0*/                   IADD3 R14, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*04c0*/                   LEA.HI.X.SX32 R12, R0, R17, 0x1, P0 ;
#         /*04d0*/                   LEA R2, P0, R9.reuse, c[0x0][0x180], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04e0*/                   ISETP.GE.AND P1, PT, R14, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*04f0*/                   LEA.HI.X R3, R9, c[0x0][0x184], R12, 0x2, P0 ;
#         /*0500*/                   STG.E.SYS [R2], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0510*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0520*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0530*/                   FFMA R13, R13, c[0x0][0x168], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0540*/                   ISETP.GE.AND P0, PT, R8, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0550*/                   STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0560*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0570*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0580*/                   FFMA R7, R10, c[0x0][0x168], R7 ;
#         /*0590*/                   FFMA R15, R15, c[0x0][0x168], R6 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*05a0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*05b0*/                   STG.E.SYS [R2+0x200], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*05c0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*05d0*/                   STG.E.SYS [R2+0x300], R15 ;
#         /*05e0*/                   EXIT ;
# .L_3172:
#         /*05f0*/                   BRA `(.L_3172);
# .L_40897:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<4, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40898 - _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R9, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R9, R9, 0x100, RZ ;
#         /*0050*/                   IADD3 R5, -R9, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0060*/                   SHF.R.S32.HI R17, RZ, 0x1f, R9 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*0070*/                   ISETP.GE.AND P0, PT, R5, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_3173) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0090*/                   IMAD.SHL.U32 R12, R9.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R17, R9, 0x2, R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 260
#         /*00b0*/                   IADD3 R8, P0, R12.reuse, c[0x0][0x188], RZ ;
#         /*00c0*/                   IADD3 R2, P1, R12, c[0x0][0x190], RZ ;
#         /*00d0*/                   IADD3.X R9, R17.reuse, c[0x0][0x18c], RZ, P0, !PT ;
#         /*00e0*/                   IADD3.X R3, R17, c[0x0][0x194], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*00f0*/                   IMAD.WIDE R8, R0, 0x10, R8 ;
#         /*0100*/                   IMAD.WIDE R2, R0, 0x10, R2 ;
#         /*0110*/                   LDG.E.128.SYS R8, [R8] ;
#         /*0120*/                   LDG.E.128.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0130*/                   IADD3 R12, P0, R12, c[0x0][0x180], RZ ;
#         /*0140*/                   IADD3.X R13, R17, c[0x0][0x184], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0150*/                   IMAD.WIDE R12, R0, 0x10, R12 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0160*/                   FFMA R7, R7, c[0x0][0x168], R11 ;
#         /*0170*/                   FFMA R6, R6, c[0x0][0x168], R10 ;
#         /*0180*/                   FFMA R5, R5, c[0x0][0x168], R9 ;
#         /*0190*/                   FFMA R4, R4, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01a0*/                   STG.E.128.SYS [R12], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*01b0*/                   EXIT ;
# .L_3173:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*01c0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
#         /*01d0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*01e0*/                   BSSY B0, `(.L_3174) ;
#         /*01f0*/               @P0 BRA `(.L_3175) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0200*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0210*/                   LEA.HI.X.SX32 R4, R0, R17, 0x1, P1 ;
#         /*0220*/                   LEA R2, P1, R3, c[0x0][0x188], 0x2 ;
#         /*0230*/                   LEA.HI.X R3, R3, c[0x0][0x18c], R4, 0x2, P1 ;
#         /*0240*/                   LDG.E.SYS R8, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0250*/                   IADD3 R4, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0260*/                   ISETP.GE.AND P1, PT, R4, R5, PT ;
#         /*0270*/               @P1 BRA `(.L_3175) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0280*/                   LDG.E.SYS R4, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0290*/                   IADD3 R6, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02a0*/                   ISETP.GE.AND P1, PT, R6, R5, PT ;
#         /*02b0*/               @P1 BRA `(.L_3175) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02c0*/                   IADD3 R10, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02d0*/                   LDG.E.SYS R7, [R2+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02e0*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02f0*/              @!P1 LDG.E.SYS R6, [R2+0x300] ;
# .L_3175:
#         /*0300*/                   BSYNC B0 ;
# .L_3174:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0310*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0320*/                   BSSY B0, `(.L_3176) ;
#         /*0330*/               @P0 BRA `(.L_3177) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0340*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0350*/                   LEA.HI.X.SX32 R10, R0, R17, 0x1, P1 ;
#         /*0360*/                   LEA R2, P1, R3, c[0x0][0x190], 0x2 ;
#         /*0370*/                   LEA.HI.X R3, R3, c[0x0][0x194], R10, 0x2, P1 ;
#         /*0380*/                   LDG.E.SYS R11, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0390*/                   IADD3 R10, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*03a0*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
#         /*03b0*/               @P1 BRA `(.L_3177) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*03c0*/                   LDG.E.SYS R13, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*03d0*/                   IADD3 R10, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*03e0*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
#         /*03f0*/               @P1 BRA `(.L_3177) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0400*/                   IADD3 R10, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0410*/                   ISETP.GE.AND P1, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0420*/                   LDG.E.SYS R10, [R2+0x200] ;
#         /*0430*/              @!P1 LDG.E.SYS R15, [R2+0x300] ;
# .L_3177:
#         /*0440*/                   BSYNC B0 ;
# .L_3176:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0450*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0460*/                   IADD3 R9, P0, R9, R0, RZ ;
#         /*0470*/                   FFMA R11, R11, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0480*/                   IADD3 R14, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0490*/                   LEA.HI.X.SX32 R12, R0, R17, 0x1, P0 ;
#         /*04a0*/                   LEA R2, P0, R9.reuse, c[0x0][0x180], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04b0*/                   ISETP.GE.AND P1, PT, R14, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*04c0*/                   LEA.HI.X R3, R9, c[0x0][0x184], R12, 0x2, P0 ;
#         /*04d0*/                   STG.E.SYS [R2], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*04e0*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*04f0*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0500*/                   FFMA R13, R13, c[0x0][0x168], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0510*/                   ISETP.GE.AND P0, PT, R8, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0520*/                   STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0530*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0540*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0550*/                   FFMA R7, R10, c[0x0][0x168], R7 ;
#         /*0560*/                   FFMA R15, R15, c[0x0][0x168], R6 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0570*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0580*/                   STG.E.SYS [R2+0x200], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0590*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*05a0*/                   STG.E.SYS [R2+0x300], R15 ;
#         /*05b0*/                   EXIT ;
# .L_3178:
#         /*05c0*/                   BRA `(.L_3178);
#         /*05d0*/                   NOP;
#         /*05e0*/                   NOP;
#         /*05f0*/                   NOP;
# .L_40898:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<1, 64, 4, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#2}, at::detail::Array<char*, 2> >(int, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#2}, at::detail::Array<char*, 2>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=16"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,(.L_40899 - _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R0, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R11, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R0, R0, 0x100, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0050*/                   SHF.R.S32.HI R3, RZ, 0x1f, R11 ;
#         /*0060*/                   IADD3 R4, P0, R0, R11, RZ ;
#         /*0070*/                   LEA.HI.X.SX32 R3, R0, R3, 0x1, P0 ;
#         /*0080*/                   IMAD.SHL.U32 R2, R4, 0x4, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0090*/                   IADD3 R0, -R0, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*00a0*/                   SHF.L.U64.HI R3, R4, 0x2, R3 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*00b0*/                   ISETP.GE.AND P0, PT, R0, 0x100, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*00c0*/                   IADD3 R4, P1, R2.reuse, c[0x0][0x198], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*00d0*/                   IADD3 R2, P2, R2, c[0x0][0x190], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*00e0*/                   IADD3.X R5, R3.reuse, c[0x0][0x19c], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*00f0*/                   IADD3.X R3, R3, c[0x0][0x194], RZ, P2, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*0100*/              @!P0 BRA `(.L_3179) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*0110*/                   LDG.E.SYS R0, [R4] ;
#         /*0120*/                   LDG.E.SYS R6, [R4+0x100] ;
#         /*0130*/                   LDG.E.SYS R8, [R4+0x200] ;
#         /*0140*/                   LDG.E.SYS R10, [R4+0x300] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0150*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
#         /*0160*/                   FFMA R7, R13.reuse, c[0x0][0x178], R0 ;
#         /*0170*/                   FFMA R9, R13.reuse, c[0x0][0x178], R6 ;
#         /*0180*/                   FFMA R11, R13, c[0x0][0x178], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0190*/                   STG.E.SYS [R2], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*01a0*/                   FFMA R13, R13, c[0x0][0x178], R10 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*01b0*/                   STG.E.SYS [R2+0x100], R9 ;
#         /*01c0*/                   STG.E.SYS [R2+0x200], R11 ;
#         /*01d0*/                   STG.E.SYS [R2+0x300], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*01e0*/                   EXIT ;
# .L_3179:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*01f0*/                   ISETP.GE.AND P0, PT, R11, R0, PT ;
#         /*0200*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0210*/                   BSSY B0, `(.L_3180) ;
#         /*0220*/               @P0 BRA `(.L_3181) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0230*/                   LDG.E.SYS R6, [R4] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0240*/                   IADD3 R7, R11, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0250*/                   ISETP.GE.AND P1, PT, R7, R0, PT ;
#         /*0260*/               @P1 BRA `(.L_3181) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0270*/                   LDG.E.SYS R7, [R4+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0280*/                   IADD3 R9, R11, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0290*/                   ISETP.GE.AND P1, PT, R9, R0, PT ;
#         /*02a0*/               @P1 BRA `(.L_3181) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02b0*/                   IADD3 R9, R11, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02c0*/                   LDG.E.SYS R8, [R4+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02d0*/                   ISETP.GE.AND P1, PT, R9, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02e0*/              @!P1 LDG.E.SYS R10, [R4+0x300] ;
# .L_3181:
#         /*02f0*/                   BSYNC B0 ;
# .L_3180:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0300*/                   IMAD.MOV.U32 R9, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0310*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0320*/                   IADD3 R13, R11, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0330*/                   FFMA R5, R9, c[0x0][0x178], R6 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0340*/                   ISETP.GE.AND P0, PT, R13, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0350*/                   STG.E.SYS [R2], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0360*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0370*/                   IADD3 R5, R11, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0380*/                   FFMA R7, R9, c[0x0][0x178], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0390*/                   ISETP.GE.AND P0, PT, R5, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*03a0*/                   STG.E.SYS [R2+0x100], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03b0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
# ...
#         /*0230*/                   LDG.E.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0240*/                   IADD3 R6, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0250*/                   ISETP.GE.AND P1, PT, R6, R7, PT ;
#         /*0260*/               @P1 BRA `(.L_3197) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0270*/                   LDG.E.SYS R6, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0280*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0290*/                   ISETP.GE.AND P1, PT, R8, R7, PT ;
#         /*02a0*/               @P1 BRA `(.L_3197) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*02b0*/                   IADD3 R8, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02c0*/                   ISETP.GE.AND P1, PT, R8, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02d0*/                   LDG.E.SYS R8, [R2+0x200] ;
#         /*02e0*/              @!P1 LDG.E.SYS R9, [R2+0x300] ;
# .L_3197:
#         /*02f0*/                   BSYNC B0 ;
# .L_3196:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0300*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0310*/                   IADD3 R3, P0, R5, R0, RZ ;
#         /*0320*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0330*/                   IADD3 R12, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0340*/                   LEA.HI.X.SX32 R10, R0, R11, 0x1, P0 ;
#         /*0350*/                   FFMA R5, R4, R13, c[0x0][0x178] ;
#         /*0360*/                   LEA R2, P0, R3.reuse, c[0x0][0x190], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0370*/                   ISETP.GE.AND P1, PT, R12, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0380*/                   LEA.HI.X R3, R3, c[0x0][0x194], R10, 0x2, P0 ;
#         /*0390*/                   STG.E.SYS [R2], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03a0*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*03b0*/                   IADD3 R4, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*03c0*/                   FFMA R5, R6, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03d0*/                   ISETP.GE.AND P0, PT, R4, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*03e0*/                   STG.E.SYS [R2+0x100], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03f0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0400*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0410*/                   FFMA R5, R8, R13.reuse, c[0x0][0x178] ;
#         /*0420*/                   FFMA R9, R9, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0430*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0440*/                   STG.E.SYS [R2+0x200], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0450*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0460*/                   STG.E.SYS [R2+0x300], R9 ;
#         /*0470*/                   EXIT ;
# .L_3198:
#         /*0480*/                   BRA `(.L_3198);
#         /*0490*/                   NOP;
#         /*04a0*/                   NOP;
#         /*04b0*/                   NOP;
#         /*04c0*/                   NOP;
#         /*04d0*/                   NOP;
#         /*04e0*/                   NOP;
#         /*04f0*/                   NOP;
# .L_40903:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<4, 64, 4, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#1}, at::detail::Array<char*, 2>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=16"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,(.L_40904 - _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R5, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 177
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 294
#         /*0040*/                   IMAD.SHL.U32 R5, R5, 0x100, RZ ;
#         /*0050*/                   IADD3 R7, -R5, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0060*/                   SHF.R.S32.HI R11, RZ, 0x1f, R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 296
#         /*0070*/                   ISETP.GE.AND P0, PT, R7, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_3199) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 260
#         /*0090*/                   IMAD.SHL.U32 R8, R5.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R11, R5, 0x2, R11 ;
#         /*00b0*/                   IADD3 R2, P0, R8, c[0x0][0x198], RZ ;
#         /*00c0*/                   IADD3.X R3, R11, c[0x0][0x19c], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 218
#         /*00d0*/                   IMAD.WIDE R2, R0, 0x10, R2 ;
#         /*00e0*/                   LDG.E.128.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*00f0*/                   IADD3 R8, P0, R8, c[0x0][0x190], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0100*/                   IMAD.MOV.U32 R10, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 256
#         /*0110*/                   IADD3.X R9, R11, c[0x0][0x194], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0120*/                   IMAD.WIDE R8, R0, 0x10, R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*0130*/                   FFMA R7, R7, R10.reuse, c[0x0][0x178] ;
#         /*0140*/                   FFMA R6, R6, R10.reuse, c[0x0][0x178] ;
#         /*0150*/                   FFMA R5, R5, R10.reuse, c[0x0][0x178] ;
#         /*0160*/                   FFMA R4, R4, R10, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 238
#         /*0170*/                   STG.E.128.SYS [R8], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 301
#         /*0180*/                   EXIT ;
# .L_3199:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0190*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
#         /*01a0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*01b0*/                   BSSY B0, `(.L_3200) ;
#         /*01c0*/               @P0 BRA `(.L_3201) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*01d0*/                   IADD3 R3, P1, R5, R0, RZ ;
#         /*01e0*/                   LEA.HI.X.SX32 R4, R0, R11, 0x1, P1 ;
#         /*01f0*/                   LEA R2, P1, R3, c[0x0][0x198], 0x2 ;
#         /*0200*/                   LEA.HI.X R3, R3, c[0x0][0x19c], R4, 0x2, P1 ;
#         /*0210*/                   LDG.E.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0220*/                   IADD3 R6, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0230*/                   ISETP.GE.AND P1, PT, R6, R7, PT ;
#         /*0240*/               @P1 BRA `(.L_3201) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*0250*/                   LDG.E.SYS R6, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0260*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*0270*/                   ISETP.GE.AND P1, PT, R8, R7, PT ;
#         /*0280*/               @P1 BRA `(.L_3201) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 184
#         /*0290*/                   IADD3 R8, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 180
#         /*02a0*/                   ISETP.GE.AND P1, PT, R8, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 183
#         /*02b0*/                   LDG.E.SYS R8, [R2+0x200] ;
#         /*02c0*/              @!P1 LDG.E.SYS R9, [R2+0x300] ;
# .L_3201:
#         /*02d0*/                   BSYNC B0 ;
# .L_3200:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*02e0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*02f0*/                   IADD3 R3, P0, R5, R0, RZ ;
#         /*0300*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0310*/                   IADD3 R12, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0320*/                   LEA.HI.X.SX32 R10, R0, R11, 0x1, P0 ;
#         /*0330*/                   FFMA R5, R4, R13, c[0x0][0x178] ;
#         /*0340*/                   LEA R2, P0, R3.reuse, c[0x0][0x190], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0350*/                   ISETP.GE.AND P1, PT, R12, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0360*/                   LEA.HI.X R3, R3, c[0x0][0x194], R10, 0x2, P0 ;
#         /*0370*/                   STG.E.SYS [R2], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0380*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*0390*/                   IADD3 R4, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*03a0*/                   FFMA R5, R6, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03b0*/                   ISETP.GE.AND P0, PT, R4, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*03c0*/                   STG.E.SYS [R2+0x100], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*03d0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 197
#         /*03e0*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/Loops.cuh", line 196
#         /*03f0*/                   FFMA R5, R8, R13.reuse, c[0x0][0x178] ;
#         /*0400*/                   FFMA R9, R9, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0410*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0420*/                   STG.E.SYS [R2+0x200], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 193
#         /*0430*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 196
#         /*0440*/                   STG.E.SYS [R2+0x300], R9 ;
#         /*0450*/                   EXIT ;
# .L_3202:
#         /*0460*/                   BRA `(.L_3202);
#         /*0470*/                   NOP;
# .L_40904:

# %% [markdown]
# # 33222

# %%
import disasm

def filter_(demangled_symbol, code):
    ret = True
    ret &= 'modern' in demangled_symbol                 # new code
    ret &= 'add_kernel' in demangled_symbol             # add kernel
    ret &= 'lambda(float, float)' in demangled_symbol   # dtype = float
    ret &= 'TypeCast.h' not in code                     # no dynamic casting
    ret &= 'OffsetCalculator.cuh' not in code           # trivial 1d
    return ret

disasm.run('BinaryArithmeticKernel.sm_70.cubin', filter_)
# Out:
# 1.5.0a0+34db65e
# 34db65e26d81b18633ddcefe00234ca774528109
#
# Running:
# rm -rf BinaryArithmeticKernel.sm_70.cubin; cuobjdump -xelf BinaryArithmeticKernel.sm_70.cubin /home/xgao/anaconda3/lib/python3.7/site-packages/torch/lib/libtorch_cuda.so
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<1, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40518 - _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R2, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 39
#         /*0030*/                   S2R R9, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0040*/                   IMAD.SHL.U32 R2, R2, 0x100, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0050*/                   SHF.R.S32.HI R3, RZ, 0x1f, R9 ;
#         /*0060*/                   IADD3 R16, P0, R2.reuse, R9, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0070*/                   IADD3 R0, -R2.reuse, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0080*/                   LEA.HI.X.SX32 R3, R2, R3, 0x1, P0 ;
#         /*0090*/                   IMAD.SHL.U32 R2, R16, 0x4, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 255
#         /*00a0*/                   ISETP.GE.AND P0, PT, R0, 0x100, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*00b0*/                   SHF.L.U64.HI R16, R16, 0x2, R3 ;
#         /*00c0*/                   IADD3 R4, P1, R2, c[0x0][0x188], RZ ;
#         /*00d0*/                   IADD3 R6, P2, R2, c[0x0][0x190], RZ ;
#         /*00e0*/                   IADD3.X R5, R16.reuse, c[0x0][0x18c], RZ, P1, !PT ;
#         /*00f0*/                   IADD3.X R7, R16, c[0x0][0x194], RZ, P2, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 82
#         /*0100*/               @P0 LDG.E.SYS R3, [R4] ;
#         /*0110*/               @P0 LDG.E.SYS R8, [R6] ;
#         /*0120*/               @P0 LDG.E.SYS R10, [R6+0x100] ;
#         /*0130*/               @P0 LDG.E.SYS R13, [R4+0x100] ;
#         /*0140*/               @P0 LDG.E.SYS R12, [R6+0x200] ;
#         /*0150*/               @P0 LDG.E.SYS R15, [R4+0x200] ;
#         /*0160*/               @P0 LDG.E.SYS R14, [R6+0x300] ;
#         /*0170*/               @P0 LDG.E.SYS R17, [R4+0x300] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0180*/                   IADD3 R2, P1, R2, c[0x0][0x180], RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0190*/               @P0 FFMA R11, R8, c[0x0][0x168], R3 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*01a0*/                   IADD3.X R3, R16, c[0x0][0x184], RZ, P1, !PT ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*01b0*/               @P0 FFMA R13, R10, c[0x0][0x168], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*01c0*/               @P0 STG.E.SYS [R2], R11 ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*01d0*/               @P0 FFMA R15, R12, c[0x0][0x168], R15 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*01e0*/               @P0 STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*01f0*/               @P0 FFMA R17, R14, c[0x0][0x168], R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0200*/               @P0 STG.E.SYS [R2+0x200], R15 ;
#         /*0210*/               @P0 STG.E.SYS [R2+0x300], R17 ;
#         /*0220*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0230*/                   ISETP.GE.AND P0, PT, R9, R0, PT ;
#         /*0240*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0250*/                   BSSY B0, `(.L_2898) ;
#         /*0260*/                   CS2R R10, SRZ ;
#         /*0270*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
#         /*0280*/                   CS2R R12, SRZ ;
#         /*0290*/               @P0 BRA `(.L_2899) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*02a0*/                   LDG.E.SYS R13, [R4] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*02b0*/                   IADD3 R11, R9, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*02c0*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
#         /*02d0*/               @P1 BRA `(.L_2900) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*02e0*/                   LDG.E.SYS R12, [R4+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*02f0*/                   IADD3 R11, R9, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0300*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
#         /*0310*/               @P1 BRA `(.L_2901) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0320*/                   IADD3 R11, R9, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0330*/                   LDG.E.SYS R10, [R4+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0340*/                   ISETP.GE.AND P1, PT, R11, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0350*/              @!P1 LDG.E.SYS R11, [R4+0x300] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0360*/               @P1 IMAD.MOV.U32 R11, RZ, RZ, RZ ;
#         /*0370*/                   BRA `(.L_2899) ;
# .L_2901:
#         /*0380*/                   CS2R R10, SRZ ;
#         /*0390*/                   BRA `(.L_2899) ;
# .L_2900:
#         /*03a0*/                   CS2R R10, SRZ ;
#         /*03b0*/                   IMAD.MOV.U32 R12, RZ, RZ, RZ ;
# .L_2899:
#         /*03c0*/                   BSYNC B0 ;
# .L_2898:
#         /*03d0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*03e0*/                   BSSY B0, `(.L_2902) ;
#         /*03f0*/               @P0 BRA `(.L_2903) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0400*/                   LDG.E.SYS R4, [R6] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0410*/                   IADD3 R5, R9, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0420*/                   ISETP.GE.AND P1, PT, R5, R0, PT ;
#         /*0430*/               @P1 BRA `(.L_2904) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0440*/                   LDG.E.SYS R5, [R6+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0450*/                   IADD3 R15, R9, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0460*/                   ISETP.GE.AND P1, PT, R15, R0, PT ;
#         /*0470*/               @P1 BRA `(.L_2905) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0480*/                   LDG.E.SYS R15, [R6+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0490*/                   IADD3 R17, R9, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*04a0*/                   ISETP.GE.AND P1, PT, R17, R0, PT ;
#         /*04b0*/               @P1 BRA `(.L_2906) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*04c0*/                   LDG.E.SYS R8, [R6+0x300] ;
#         /*04d0*/                   BRA `(.L_2906) ;
# .L_2905:
#         /*04e0*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*04f0*/                   BRA `(.L_2906) ;
# .L_2904:
#         /*0500*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*0510*/                   IMAD.MOV.U32 R5, RZ, RZ, RZ ;
#         /*0520*/                   BRA `(.L_2906) ;
# .L_2903:
#         /*0530*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*0540*/                   CS2R R4, SRZ ;
# .L_2906:
#         /*0550*/                   BSYNC B0 ;
# .L_2902:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0560*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0570*/                   IADD3 R7, R9, 0x40, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0580*/                   FFMA R13, R4, c[0x0][0x168], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0590*/                   ISETP.GE.AND P0, PT, R7, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*05a0*/                   STG.E.SYS [R2], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*05b0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*05c0*/                   IADD3 R7, R9, 0x80, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*05d0*/                   FFMA R5, R5, c[0x0][0x168], R12 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*05e0*/                   ISETP.GE.AND P0, PT, R7, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*05f0*/                   STG.E.SYS [R2+0x100], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0600*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0610*/                   IADD3 R9, R9, 0xc0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0620*/                   FFMA R15, R15, c[0x0][0x168], R10 ;
#         /*0630*/                   FFMA R11, R8, c[0x0][0x168], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0640*/                   ISETP.GE.AND P0, PT, R9, R0, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0650*/                   STG.E.SYS [R2+0x200], R15 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0660*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0670*/                   STG.E.SYS [R2+0x300], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 260
#         /*0680*/                   EXIT ;
# .L_2907:
#         /*0690*/                   BRA `(.L_2907);
#         /*06a0*/                   NOP;
#         /*06b0*/                   NOP;
#         /*06c0*/                   NOP;
#         /*06d0*/                   NOP;
#         /*06e0*/                   NOP;
#         /*06f0*/                   NOP;
# .L_40518:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<2, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40519 - _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi2ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R9, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 39
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0040*/                   IMAD.SHL.U32 R9, R9, 0x100, RZ ;
#         /*0050*/                   IADD3 R5, -R9, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0060*/                   SHF.R.S32.HI R17, RZ, 0x1f, R9 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 255
#         /*0070*/                   ISETP.GE.AND P0, PT, R5, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_2908) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0090*/                   IMAD.SHL.U32 R14, R9.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R17, R9, 0x2, R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 229
#         /*00b0*/                   IADD3 R10, P0, R14.reuse, c[0x0][0x188], RZ ;
#         /*00c0*/                   IADD3 R12, P1, R14, c[0x0][0x190], RZ ;
#         /*00d0*/                   IADD3.X R11, R17.reuse, c[0x0][0x18c], RZ, P0, !PT ;
#         /*00e0*/                   IADD3.X R13, R17, c[0x0][0x194], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 82
#         /*00f0*/                   IMAD.WIDE R10, R0, 0x8, R10 ;
#         /*0100*/                   IMAD.WIDE R12, R0, 0x8, R12 ;
#         /*0110*/                   LDG.E.64.SYS R8, [R10] ;
#         /*0120*/                   LDG.E.64.SYS R2, [R12] ;
#         /*0130*/                   LDG.E.64.SYS R4, [R10+0x200] ;
#         /*0140*/                   LDG.E.64.SYS R6, [R12+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0150*/                   IADD3 R14, P0, R14, c[0x0][0x180], RZ ;
#         /*0160*/                   IADD3.X R15, R17, c[0x0][0x184], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0170*/                   IMAD.WIDE R14, R0, 0x8, R14 ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0180*/                   FFMA R3, R3, c[0x0][0x168], R9 ;
#         /*0190*/                   FFMA R2, R2, c[0x0][0x168], R8 ;
#         /*01a0*/                   FFMA R5, R7, c[0x0][0x168], R5 ;
#         /*01b0*/                   FFMA R4, R6, c[0x0][0x168], R4 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*01c0*/                   STG.E.64.SYS [R14], R2 ;
#         /*01d0*/                   STG.E.64.SYS [R14+0x200], R4 ;
#         /*01e0*/                   EXIT ;
# .L_2908:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*01f0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
#         /*0200*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0210*/                   BSSY B0, `(.L_2909) ;
#         /*0220*/                   IMAD.MOV.U32 R4, RZ, RZ, RZ ;
#         /*0230*/                   CS2R R6, SRZ ;
#         /*0240*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
#         /*0250*/                   IMAD.MOV.U32 R10, RZ, RZ, RZ ;
#         /*0260*/               @P0 BRA `(.L_2910) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0270*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0280*/                   LEA.HI.X.SX32 R6, R0, R17, 0x1, P1 ;
#         /*0290*/                   LEA R2, P1, R3, c[0x0][0x188], 0x2 ;
#         /*02a0*/                   LEA.HI.X R3, R3, c[0x0][0x18c], R6, 0x2, P1 ;
#         /*02b0*/                   LDG.E.SYS R10, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*02c0*/                   IADD3 R6, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*02d0*/                   ISETP.GE.AND P1, PT, R6, R5, PT ;
#         /*02e0*/               @P1 BRA `(.L_2911) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*02f0*/                   LDG.E.SYS R6, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0300*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0310*/                   ISETP.GE.AND P1, PT, R8, R5, PT ;
#         /*0320*/               @P1 BRA `(.L_2912) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0330*/                   IADD3 R8, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0340*/                   ISETP.GE.AND P1, PT, R8, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0350*/                   LDG.E.SYS R8, [R2+0x200] ;
#         /*0360*/              @!P1 LDG.E.SYS R7, [R2+0x300] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0370*/               @P1 IMAD.MOV.U32 R7, RZ, RZ, RZ ;
#         /*0380*/                   BRA `(.L_2910) ;
# .L_2912:
#         /*0390*/                   IMAD.MOV.U32 R7, RZ, RZ, RZ ;
#         /*03a0*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
#         /*03b0*/                   BRA `(.L_2910) ;
# .L_2911:
#         /*03c0*/                   CS2R R6, SRZ ;
#         /*03d0*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
# .L_2910:
#         /*03e0*/                   BSYNC B0 ;
# .L_2909:
#         /*03f0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*0400*/                   BSSY B0, `(.L_2913) ;
#         /*0410*/               @P0 BRA `(.L_2914) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0420*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0430*/                   LEA.HI.X.SX32 R12, R0, R17, 0x1, P1 ;
#         /*0440*/                   LEA R2, P1, R3, c[0x0][0x190], 0x2 ;
#         /*0450*/                   LEA.HI.X R3, R3, c[0x0][0x194], R12, 0x2, P1 ;
#         /*0460*/                   LDG.E.SYS R11, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0470*/                   IADD3 R12, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0480*/                   ISETP.GE.AND P1, PT, R12, R5, PT ;
#         /*0490*/               @P1 BRA `(.L_2915) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*04a0*/                   LDG.E.SYS R13, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*04b0*/                   IADD3 R12, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*04c0*/                   ISETP.GE.AND P1, PT, R12, R5, PT ;
#         /*04d0*/               @P1 BRA `(.L_2916) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*04e0*/                   LDG.E.SYS R15, [R2+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*04f0*/                   IADD3 R12, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0500*/                   ISETP.GE.AND P1, PT, R12, R5, PT ;
#         /*0510*/               @P1 BRA `(.L_2917) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0520*/                   LDG.E.SYS R4, [R2+0x300] ;
#         /*0530*/                   BRA `(.L_2917) ;
# .L_2916:
#         /*0540*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*0550*/                   BRA `(.L_2917) ;
# .L_2915:
#         /*0560*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*0570*/                   IMAD.MOV.U32 R13, RZ, RZ, RZ ;
#         /*0580*/                   BRA `(.L_2917) ;
# .L_2914:
#         /*0590*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*05a0*/                   IMAD.MOV.U32 R13, RZ, RZ, RZ ;
#         /*05b0*/                   IMAD.MOV.U32 R11, RZ, RZ, RZ ;
# .L_2917:
#         /*05c0*/                   BSYNC B0 ;
# .L_2913:
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*05d0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*05e0*/                   IADD3 R9, P0, R9, R0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*05f0*/                   FFMA R11, R11, c[0x0][0x168], R10 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0600*/                   IADD3 R14, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0610*/                   LEA.HI.X.SX32 R12, R0, R17, 0x1, P0 ;
#         /*0620*/                   LEA R2, P0, R9.reuse, c[0x0][0x180], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0630*/                   ISETP.GE.AND P1, PT, R14, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0640*/                   LEA.HI.X R3, R9, c[0x0][0x184], R12, 0x2, P0 ;
#         /*0650*/                   STG.E.SYS [R2], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0660*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0670*/                   IADD3 R10, R0, 0x80, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0680*/                   FFMA R13, R13, c[0x0][0x168], R6 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0690*/                   ISETP.GE.AND P0, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*06a0*/                   STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*06b0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*06c0*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*06d0*/                   FFMA R15, R15, c[0x0][0x168], R8 ;
#         /*06e0*/                   FFMA R7, R4, c[0x0][0x168], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*06f0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0700*/                   STG.E.SYS [R2+0x200], R15 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0710*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0720*/                   STG.E.SYS [R2+0x300], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 260
#         /*0730*/                   EXIT ;
# .L_2918:
#         /*0740*/                   BRA `(.L_2918);
#         /*0750*/                   NOP;
#         /*0760*/                   NOP;
#         /*0770*/                   NOP;
# .L_40519:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<4, 64, 4, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3> >(int, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}, at::detail::Array<char*, 3>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=20"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,(.L_40520 - _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_NS_6detail5ArrayIPcLi3EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R9, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 39
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0040*/                   IMAD.SHL.U32 R9, R9, 0x100, RZ ;
#         /*0050*/                   IADD3 R5, -R9, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0060*/                   SHF.R.S32.HI R17, RZ, 0x1f, R9 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 255
#         /*0070*/                   ISETP.GE.AND P0, PT, R5, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_2919) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0090*/                   IMAD.SHL.U32 R12, R9.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R17, R9, 0x2, R17 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 229
#         /*00b0*/                   IADD3 R8, P0, R12.reuse, c[0x0][0x188], RZ ;
#         /*00c0*/                   IADD3 R2, P1, R12, c[0x0][0x190], RZ ;
#         /*00d0*/                   IADD3.X R9, R17.reuse, c[0x0][0x18c], RZ, P0, !PT ;
#         /*00e0*/                   IADD3.X R3, R17, c[0x0][0x194], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 82
#         /*00f0*/                   IMAD.WIDE R8, R0, 0x10, R8 ;
#         /*0100*/                   IMAD.WIDE R2, R0, 0x10, R2 ;
#         /*0110*/                   LDG.E.128.SYS R8, [R8] ;
#         /*0120*/                   LDG.E.128.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0130*/                   IADD3 R12, P0, R12, c[0x0][0x180], RZ ;
#         /*0140*/                   IADD3.X R13, R17, c[0x0][0x184], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0150*/                   IMAD.WIDE R12, R0, 0x10, R12 ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0160*/                   FFMA R7, R7, c[0x0][0x168], R11 ;
#         /*0170*/                   FFMA R6, R6, c[0x0][0x168], R10 ;
#         /*0180*/                   FFMA R5, R5, c[0x0][0x168], R9 ;
#         /*0190*/                   FFMA R4, R4, c[0x0][0x168], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*01a0*/                   STG.E.128.SYS [R12], R4 ;
#         /*01b0*/                   EXIT ;
# .L_2919:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*01c0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
#         /*01d0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*01e0*/                   BSSY B0, `(.L_2920) ;
#         /*01f0*/                   IMAD.MOV.U32 R4, RZ, RZ, RZ ;
#         /*0200*/                   CS2R R6, SRZ ;
#         /*0210*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
#         /*0220*/                   IMAD.MOV.U32 R10, RZ, RZ, RZ ;
#         /*0230*/               @P0 BRA `(.L_2921) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0240*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0250*/                   LEA.HI.X.SX32 R6, R0, R17, 0x1, P1 ;
#         /*0260*/                   LEA R2, P1, R3, c[0x0][0x188], 0x2 ;
#         /*0270*/                   LEA.HI.X R3, R3, c[0x0][0x18c], R6, 0x2, P1 ;
#         /*0280*/                   LDG.E.SYS R10, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0290*/                   IADD3 R6, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*02a0*/                   ISETP.GE.AND P1, PT, R6, R5, PT ;
#         /*02b0*/               @P1 BRA `(.L_2922) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*02c0*/                   LDG.E.SYS R6, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*02d0*/                   IADD3 R8, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*02e0*/                   ISETP.GE.AND P1, PT, R8, R5, PT ;
#         /*02f0*/               @P1 BRA `(.L_2923) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0300*/                   IADD3 R8, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0310*/                   ISETP.GE.AND P1, PT, R8, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0320*/                   LDG.E.SYS R8, [R2+0x200] ;
#         /*0330*/              @!P1 LDG.E.SYS R7, [R2+0x300] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0340*/               @P1 IMAD.MOV.U32 R7, RZ, RZ, RZ ;
#         /*0350*/                   BRA `(.L_2921) ;
# .L_2923:
#         /*0360*/                   IMAD.MOV.U32 R7, RZ, RZ, RZ ;
#         /*0370*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
#         /*0380*/                   BRA `(.L_2921) ;
# .L_2922:
#         /*0390*/                   CS2R R6, SRZ ;
#         /*03a0*/                   IMAD.MOV.U32 R8, RZ, RZ, RZ ;
# .L_2921:
#         /*03b0*/                   BSYNC B0 ;
# .L_2920:
#         /*03c0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*03d0*/                   BSSY B0, `(.L_2924) ;
#         /*03e0*/               @P0 BRA `(.L_2925) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*03f0*/                   IADD3 R3, P1, R9, R0, RZ ;
#         /*0400*/                   LEA.HI.X.SX32 R12, R0, R17, 0x1, P1 ;
#         /*0410*/                   LEA R2, P1, R3, c[0x0][0x190], 0x2 ;
#         /*0420*/                   LEA.HI.X R3, R3, c[0x0][0x194], R12, 0x2, P1 ;
#         /*0430*/                   LDG.E.SYS R11, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0440*/                   IADD3 R12, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0450*/                   ISETP.GE.AND P1, PT, R12, R5, PT ;
#         /*0460*/               @P1 BRA `(.L_2926) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0470*/                   LDG.E.SYS R13, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0480*/                   IADD3 R12, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0490*/                   ISETP.GE.AND P1, PT, R12, R5, PT ;
#         /*04a0*/               @P1 BRA `(.L_2927) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*04b0*/                   LDG.E.SYS R15, [R2+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*04c0*/                   IADD3 R12, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*04d0*/                   ISETP.GE.AND P1, PT, R12, R5, PT ;
#         /*04e0*/               @P1 BRA `(.L_2928) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*04f0*/                   LDG.E.SYS R4, [R2+0x300] ;
#         /*0500*/                   BRA `(.L_2928) ;
# .L_2927:
#         /*0510*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*0520*/                   BRA `(.L_2928) ;
# .L_2926:
#         /*0530*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*0540*/                   IMAD.MOV.U32 R13, RZ, RZ, RZ ;
#         /*0550*/                   BRA `(.L_2928) ;
# .L_2925:
#         /*0560*/                   IMAD.MOV.U32 R15, RZ, RZ, RZ ;
#         /*0570*/                   IMAD.MOV.U32 R13, RZ, RZ, RZ ;
#         /*0580*/                   IMAD.MOV.U32 R11, RZ, RZ, RZ ;
# .L_2928:
#         /*0590*/                   BSYNC B0 ;
# .L_2924:
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*05a0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*05b0*/                   IADD3 R9, P0, R9, R0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*05c0*/                   FFMA R11, R11, c[0x0][0x168], R10 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*05d0*/                   IADD3 R14, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*05e0*/                   LEA.HI.X.SX32 R12, R0, R17, 0x1, P0 ;
#         /*05f0*/                   LEA R2, P0, R9.reuse, c[0x0][0x180], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0600*/                   ISETP.GE.AND P1, PT, R14, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0610*/                   LEA.HI.X R3, R9, c[0x0][0x184], R12, 0x2, P0 ;
#         /*0620*/                   STG.E.SYS [R2], R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0630*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0640*/                   IADD3 R10, R0, 0x80, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0650*/                   FFMA R13, R13, c[0x0][0x168], R6 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0660*/                   ISETP.GE.AND P0, PT, R10, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0670*/                   STG.E.SYS [R2+0x100], R13 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0680*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0690*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*06a0*/                   FFMA R15, R15, c[0x0][0x168], R8 ;
#         /*06b0*/                   FFMA R7, R4, c[0x0][0x168], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*06c0*/                   ISETP.GE.AND P0, PT, R0, R5, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*06d0*/                   STG.E.SYS [R2+0x200], R15 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*06e0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*06f0*/                   STG.E.SYS [R2+0x300], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 260
#         /*0700*/                   EXIT ;
# .L_2929:
#         /*0710*/                   BRA `(.L_2929);
#         /*0720*/                   NOP;
#         /*0730*/                   NOP;
#         /*0740*/                   NOP;
#         /*0750*/                   NOP;
#         /*0760*/                   NOP;
#         /*0770*/                   NOP;
# .L_40520:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<1, 64, 4, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#2}, at::detail::Array<char*, 2> >(int, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#2}, at::detail::Array<char*, 2>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=16"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,(.L_40521 - _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi1ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE0_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R0, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 39
#         /*0030*/                   S2R R11, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0040*/                   IMAD.SHL.U32 R0, R0, 0x100, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0050*/                   SHF.R.S32.HI R3, RZ, 0x1f, R11 ;
#         /*0060*/                   IADD3 R4, P0, R0, R11, RZ ;
#         /*0070*/                   LEA.HI.X.SX32 R3, R0, R3, 0x1, P0 ;
#         /*0080*/                   IMAD.SHL.U32 R2, R4, 0x4, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0090*/                   IADD3 R0, -R0, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*00a0*/                   SHF.L.U64.HI R3, R4, 0x2, R3 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 255
#         /*00b0*/                   ISETP.GE.AND P0, PT, R0, 0x100, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*00c0*/                   IADD3 R4, P1, R2.reuse, c[0x0][0x198], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*00d0*/                   IADD3 R2, P2, R2, c[0x0][0x190], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*00e0*/                   IADD3.X R5, R3.reuse, c[0x0][0x19c], RZ, P1, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*00f0*/                   IADD3.X R3, R3, c[0x0][0x194], RZ, P2, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 255
#         /*0100*/              @!P0 BRA `(.L_2930) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 82
#         /*0110*/                   LDG.E.SYS R0, [R4] ;
#         /*0120*/                   LDG.E.SYS R6, [R4+0x100] ;
#         /*0130*/                   LDG.E.SYS R8, [R4+0x200] ;
#         /*0140*/                   LDG.E.SYS R10, [R4+0x300] ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0150*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
#         /*0160*/                   FFMA R7, R13.reuse, c[0x0][0x178], R0 ;
#         /*0170*/                   FFMA R9, R13.reuse, c[0x0][0x178], R6 ;
#         /*0180*/                   FFMA R11, R13, c[0x0][0x178], R8 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0190*/                   STG.E.SYS [R2], R7 ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*01a0*/                   FFMA R13, R13, c[0x0][0x178], R10 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
# ...
#         /*0380*/                   CS2R R8, SRZ ;
# .L_2963:
#         /*0390*/                   BSYNC B0 ;
# .L_2959:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*03a0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*03b0*/                   IADD3 R3, P0, R5, R0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*03c0*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*03d0*/                   IADD3 R12, R0.reuse, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*03e0*/                   LEA.HI.X.SX32 R6, R0, R11, 0x1, P0 ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*03f0*/                   FFMA R5, R8, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0400*/                   LEA R2, P0, R3, c[0x0][0x190], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0410*/                   ISETP.GE.AND P1, PT, R12, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0420*/                   LEA.HI.X R3, R3, c[0x0][0x194], R6, 0x2, P0 ;
#         /*0430*/                   STG.E.SYS [R2], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0440*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0450*/                   IADD3 R6, R0, 0x80, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0460*/                   FFMA R9, R9, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0470*/                   ISETP.GE.AND P0, PT, R6, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0480*/                   STG.E.SYS [R2+0x100], R9 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0490*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*04a0*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*04b0*/                   FFMA R5, R10, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*04c0*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*04d0*/                   FFMA R7, R4, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*04e0*/                   STG.E.SYS [R2+0x200], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*04f0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0500*/                   STG.E.SYS [R2+0x300], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 260
#         /*0510*/                   EXIT ;
# .L_2964:
#         /*0520*/                   BRA `(.L_2964);
#         /*0530*/                   NOP;
#         /*0540*/                   NOP;
#         /*0550*/                   NOP;
#         /*0560*/                   NOP;
#         /*0570*/                   NOP;
# .L_40525:
#
# **Symbol:**
# void at::native::modern::elementwise_kernel<4, 64, 4, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::gpu_kernel_with_scalars<at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>(at::TensorIterator&, at::native::add_kernel_cuda(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1} const&)::{lambda(float)#1}, at::detail::Array<char*, 2>)
#
# **ASM:**
#
# 	.section	.text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,"ax",@progbits
# 	.sectioninfo	@"SHI_REGISTERS=16"
# 	.align	128
#         .global         _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_
#         .type           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@function
#         .size           _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,(.L_40526 - _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_)
#         .other          _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_,@"STO_CUDA_ENTRY STV_DEFAULT"
# _ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# .text._ZN2at6native6modern18elementwise_kernelILi4ELi64ELi4EZNS0_23gpu_kernel_with_scalarsIZZZNS0_15add_kernel_cudaERNS_14TensorIteratorEN3c106ScalarEENKUlvE_clEvENKUlvE2_clEvEUlffE_EEvS5_RKT_EUlfE_NS_6detail5ArrayIPcLi2EEEEEviT2_T3_:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0000*/                   IMAD.MOV.U32 R1, RZ, RZ, c[0x0][0x28] ;
#         /*0010*/              @!PT SHFL.IDX PT, RZ, RZ, RZ, RZ ;
#         /*0020*/                   S2R R5, SR_CTAID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 39
#         /*0030*/                   S2R R0, SR_TID.X ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 253
#         /*0040*/                   IMAD.SHL.U32 R5, R5, 0x100, RZ ;
#         /*0050*/                   IADD3 R7, -R5, c[0x0][0x160], RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0060*/                   SHF.R.S32.HI R11, RZ, 0x1f, R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 255
#         /*0070*/                   ISETP.GE.AND P0, PT, R7, 0x100, PT ;
#         /*0080*/              @!P0 BRA `(.L_2965) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0090*/                   IMAD.SHL.U32 R8, R5.reuse, 0x4, RZ ;
#         /*00a0*/                   SHF.L.U64.HI R11, R5, 0x2, R11 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 229
#         /*00b0*/                   IADD3 R2, P0, R8, c[0x0][0x198], RZ ;
#         /*00c0*/                   IADD3.X R3, R11, c[0x0][0x19c], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 82
#         /*00d0*/                   IMAD.WIDE R2, R0, 0x10, R2 ;
#         /*00e0*/                   LDG.E.128.SYS R4, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*00f0*/                   IADD3 R8, P0, R8, c[0x0][0x190], RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0100*/                   IMAD.MOV.U32 R10, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 227
#         /*0110*/                   IADD3.X R9, R11, c[0x0][0x194], RZ, P0, !PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0120*/                   IMAD.WIDE R8, R0, 0x10, R8 ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0130*/                   FFMA R7, R7, R10.reuse, c[0x0][0x178] ;
#         /*0140*/                   FFMA R6, R6, R10.reuse, c[0x0][0x178] ;
#         /*0150*/                   FFMA R5, R5, R10.reuse, c[0x0][0x178] ;
#         /*0160*/                   FFMA R4, R4, R10, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0170*/                   STG.E.128.SYS [R8], R4 ;
#         /*0180*/                   EXIT ;
# .L_2965:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0190*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
#         /*01a0*/                   BMOV.32.CLEAR RZ, B0 ;
#         /*01b0*/                   BSSY B0, `(.L_2966) ;
#         /*01c0*/                   IMAD.MOV.U32 R4, RZ, RZ, RZ ;
#         /*01d0*/               @P0 BRA `(.L_2967) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*01e0*/                   IADD3 R3, P1, R5, R0, RZ ;
#         /*01f0*/                   LEA.HI.X.SX32 R6, R0, R11, 0x1, P1 ;
#         /*0200*/                   LEA R2, P1, R3, c[0x0][0x198], 0x2 ;
#         /*0210*/                   LEA.HI.X R3, R3, c[0x0][0x19c], R6, 0x2, P1 ;
#         /*0220*/                   LDG.E.SYS R8, [R2] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0230*/                   IADD3 R6, R0, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0240*/                   ISETP.GE.AND P1, PT, R6, R7, PT ;
#         /*0250*/               @P1 BRA `(.L_2968) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*0260*/                   LDG.E.SYS R9, [R2+0x100] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*0270*/                   IADD3 R6, R0, 0x80, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*0280*/                   ISETP.GE.AND P1, PT, R6, R7, PT ;
#         /*0290*/               @P1 BRA `(.L_2969) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*02a0*/                   LDG.E.SYS R10, [R2+0x200] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 46
#         /*02b0*/                   IADD3 R6, R0, 0xc0, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 42
#         /*02c0*/                   ISETP.GE.AND P1, PT, R6, R7, PT ;
#         /*02d0*/               @P1 BRA `(.L_2970) ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 45
#         /*02e0*/                   LDG.E.SYS R4, [R2+0x300] ;
#         /*02f0*/                   BRA `(.L_2970) ;
# .L_2969:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 102
#         /*0300*/                   IMAD.MOV.U32 R10, RZ, RZ, RZ ;
#         /*0310*/                   BRA `(.L_2970) ;
# .L_2968:
#         /*0320*/                   IMAD.MOV.U32 R10, RZ, RZ, RZ ;
#         /*0330*/                   IMAD.MOV.U32 R9, RZ, RZ, RZ ;
#         /*0340*/                   BRA `(.L_2970) ;
# .L_2967:
#         /*0350*/                   IMAD.MOV.U32 R10, RZ, RZ, RZ ;
#         /*0360*/                   CS2R R8, SRZ ;
# .L_2970:
#         /*0370*/                   BSYNC B0 ;
# .L_2966:
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0380*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0390*/                   IADD3 R3, P0, R5, R0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*03a0*/                   IMAD.MOV.U32 R13, RZ, RZ, c[0x0][0x168] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*03b0*/                   IADD3 R12, R0.reuse, 0x40, RZ ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*03c0*/                   LEA.HI.X.SX32 R6, R0, R11, 0x1, P0 ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*03d0*/                   FFMA R5, R8, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*03e0*/                   LEA R2, P0, R3, c[0x0][0x190], 0x2 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*03f0*/                   ISETP.GE.AND P1, PT, R12, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0400*/                   LEA.HI.X R3, R3, c[0x0][0x194], R6, 0x2, P0 ;
#         /*0410*/                   STG.E.SYS [R2], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0420*/               @P1 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0430*/                   IADD3 R6, R0, 0x80, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0440*/                   FFMA R9, R9, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0450*/                   ISETP.GE.AND P0, PT, R6, R7, PT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*0460*/                   STG.E.SYS [R2+0x100], R9 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*0470*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 59
#         /*0480*/                   IADD3 R0, R0, 0xc0, RZ ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*0490*/                   FFMA R5, R10, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*04a0*/                   ISETP.GE.AND P0, PT, R0, R7, PT ;
# 	//## File "/usr/include/c++/8/tuple", line 1315
#         /*04b0*/                   FFMA R7, R4, R13, c[0x0][0x178] ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*04c0*/                   STG.E.SYS [R2+0x200], R5 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 55
#         /*04d0*/               @P0 EXIT ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/MemoryAccess.cuh", line 58
#         /*04e0*/                   STG.E.SYS [R2+0x300], R7 ;
# 	//## File "/home/xgao/pytorch/aten/src/ATen/native/cuda/CUDALoops.cuh", line 260
#         /*04f0*/                   EXIT ;
# .L_2971:
#         /*0500*/                   BRA `(.L_2971);
#         /*0510*/                   NOP;
#         /*0520*/                   NOP;
#         /*0530*/                   NOP;
#         /*0540*/                   NOP;
#         /*0550*/                   NOP;
#         /*0560*/                   NOP;
#         /*0570*/                   NOP;
# .L_40526:
